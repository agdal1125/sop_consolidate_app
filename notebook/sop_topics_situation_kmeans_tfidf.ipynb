# %%
import os
import json
from docx import Document
from io import StringIO, BytesIO
import re
import time
import datetime

import pandas as pd
import json
import spacy
from nltk.corpus import stopwords

from gensim.models import LdaModel
from gensim.models.wrappers import LdaMallet
import gensim.corpora as corpora
from gensim.corpora import Dictionary
from gensim import matutils, models
from gensim.models import CoherenceModel, TfidfModel, HdpModel
from gensim.models.phrases import Phrases, Phraser
import pyLDAvis.gensim

from sklearn.cluster import KMeans
from scipy.sparse import csc_matrix
from gensim.matutils import corpus2csc
from matplotlib.ticker import MaxNLocator
from sklearn.metrics import silhouette_score
from sklearn.metrics.pairwise import cosine_similarity

from docx import Document
from io import StringIO, BytesIO
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'font.size': 14, 'lines.linewidth': 3})

# %%
nlp = spacy.load("en_core_web_sm")
# stop_words = set(stopwords.words('english'))

# %%
notebook_dir = os.getcwd()
situ_df = pd.read_csv('../data/interim/calltaker_situation.csv', 
                      keep_default_na = False, 
                     converters = {'sop': eval})

# %%
# situ_df = situ_df[situ_df['situation'].str.len() > 0].reset_index(drop = True)
situ_df
# Out:
#         type juri        role                                    situation  \
# 0       1033   DE  call taker                            CBSA alarm policy
# 1       DOMI   AB  call taker                       All other DOMI reports
# 2       DOMI   AB  call taker                             GPS Panic Alarms
# 3     FOUNDP   AB  call taker                             Address Obtained
# 4     FOUNDP   AB  call taker                 Name or medic alert is known
# ...      ...  ...         ...                                          ...
# 3589  ALARMD   AB  call taker  All Other DVERS personal residential alarms
# 3590  ALARMD   AB  call taker                      DVERS Alarm maintenance
# 3591  ALARMD   AB  call taker                     GPS tracked Panic Alarms
# 3592     DNA   NW  call taker                                 DNA Warrant:
# 3593     DNA   RI  call taker                                 DNA Warrant:
#
#                                                     sop  \
# 0     [Listen to alarm, Acknowledge the alarm by pre...
# 1     [Create a call in every instance. Do not cance...
# 2     [Create a call, Remain on the line recording a...
# 3     [Run address on QBA:, If the person is negativ...
# 4     [Run name on CPIC, If the person is negative o...
# ...                                                 ...
# 3589  [Create a call, Check hazards which will show ...
# 3590  [See “Assist GP”  for a stand by keep the peac...
# 3591                                      [See AB-DOMI]
# 3592                        [See WARRAN (Warrants) SOP]
# 3593                        [See WARRAN (Warrants) SOP]
#
#                                         filename
# 0            DE - 1033 - Officer in trouble.docx
# 1          AB - DOMI - Domestic in progress.docx
# 2          AB - DOMI - Domestic in progress.docx
# 3                AB - FOUNDP - Found Person.docx
# 4                AB - FOUNDP - Found Person.docx
# ...                                          ...
# 3589  AB - ALARMD - Domestic violence alarm.docx
# 3590  AB - ALARMD - Domestic violence alarm.docx
# 3591  AB - ALARMD - Domestic violence alarm.docx
# 3592             NW - DNA - DNA collection .docx
# 3593              RI - DNA - DNA collection.docx
#
# [3594 rows x 6 columns]

# %%
def preprocess(strlist,
               min_token_len = 2,
               allowed_pos = ['ADV', 'ADJ', 'VERB', 'NOUN', 'PART', 'NUM', 'PROPN']): 
    removal = ['-', r'i\.e\.']
    res = list()
    not_stopword = {'call'}
    for string in strlist:
        text = re.sub(r"|".join(removal), ' ', string.lower())
        doc = nlp(text)
        res += [token.lemma_ for token in doc \
               if token.pos_ in allowed_pos \
               # Spacy considers 'call' as a stop word, which is not suitable for our case
               and (token.text in not_stopword or not token.is_stop) \
#                and token.text not in stop_words \              
#                and token.is_alpha \
               and len(token.lemma_) > min_token_len
               ]
    
    return ' '.join(res)

# %%
def get_dct_dtmatrix(sops):
    corpus = [sop.split() for sop in map(preprocess, sops)]
#     phrases = Phrases(corpus, min_count = 1, threshold = 1)
#     bigram = Phraser(phrases)
#     corpus = bigram(corpus)
    dictionary = corpora.Dictionary(corpus)
    doc_term_matrix = [dictionary.doc2bow(doc) for doc in corpus]
    return doc_term_matrix, corpus, dictionary

# %%
doc_term_bow, corpus, dictionary = get_dct_dtmatrix(situ_df['sop'])

# %%
def bow2tfidf(doc_term_bow, corpus_tfidf):
    doc_term_tfidf = corpus_tfidf[doc_term_bow]
    scipy_tfidf = corpus2csc(doc_term_tfidf, num_terms = len(corpus_tfidf.idfs))
    tfidf_mtx = csc_matrix(scipy_tfidf).T.toarray()
#     print(f'The dimensions of tfidf matrix = {tfidf_mtx.shape}')
    return tfidf_mtx

# %%
tfidf_situ = TfidfModel(doc_term_bow)
tfidf_mtx = bow2tfidf(doc_term_bow, tfidf_situ)

# %%
def save_df(df, name, prefix = '../data/interim/'):
    filename = prefix + name
    df.to_csv(filename, index = False)

# %% [markdown]
# ### Finding the best `n_clusters` for KMeans
# > use code below to fit multiple models with different `n_clusters`:
# ```python
# kms = list()
# for k in range(1, 300):
#     km = KMeans(n_clusters = k).fit(tfidf_mtx)
#     kms.append(km)
# ```
#
# > use code below to find the elbow of inertias:
# ```python
# fig, ax = plt.subplots(1, 1, figsize = (12, 4))
# ax.plot(range(1, 300),
#         [km.inertia_ for km in kms])
# ax.set_xlabel('k')
# ax.set_ylabel('inertia')
# ax.set_title(f'Inertia vs Number of Clusters')
# ax.xaxis.set_major_locator(MaxNLocator(integer = True))
# ax.grid()
# plt.show()
# ```
# ![](img/kmeans_inertias.PNG)
#
# > use code below to find the shoulder of Silhouette scores
# ```python
# fig, ax = plt.subplots(1, 1, figsize = (12, 4))
# ax.plot(range(2, 300),
#         [silhouette_score(tfidf_mtx, kms[k-1].labels_) for k in range(2, 300)])
# ax.set_xlabel('k')
# ax.set_ylabel('silhouette_score')
# ax.set_title(f'Silhouette Score vs Number of Clusters')
# ax.xaxis.set_major_locator(MaxNLocator(integer = True))
# ax.grid()
# plt.show()
# ```
# ![](img/kmeans_silhouette.PNG)
#
# #### Based on the plots of inertias and Silhouette scores, we choose k = 190

# %%
km_190 = KMeans(n_clusters = 190, random_state = 2020).fit(tfidf_mtx)

# %%
situ_topics_kmeans_tfidf = situ_df.copy()
situ_topics_kmeans_tfidf['cluster'] = km_190.labels_
situ_topics_kmeans_tfidf = situ_topics_kmeans_tfidf.sort_values(by = ['cluster', 'type', 'juri'], ignore_index = True)

# %%
situ_topics_kmeans_tfidf#[situ_topics_kmeans_tfidf['cluster'] == 91]['situation'].tolist()
# Out:
#         type juri        role                                   situation  \
# 0      FRAUD   AB  call taker               Not in progress – All reports
# 1       PROP   AB  call taker     Lost license plates and validation tags
# 2       PROP   BI  call taker  Lost license plates and/or validation tags
# 3       PROP   BU  call taker    Lost licence plate and/or validation tag
# 4       PROP   DE  call taker     Lost license plates and validation tags
# ...      ...  ...         ...                                         ...
# 3589  ANIMAL   SX  call taker                            Deceased animals
# 3590  ANIMAL   UN  call taker                            Deceased animals
# 3591   ASSOA   DE  call taker                           General Procedure
# 3592   ASSOA   SX  call taker                           General Procedure
# 3593   ASSOA   WV  call taker                           General Procedure
#
#                                                     sop  \
# 0                          [Transfer to a Report Agent]
# 1                     [Transfer call to a Report Agent]
# 2                     [Transfer call to a Report Agent]
# 3                          [Transfer to a Report Agent]
# 4                     [Transfer call to a Report Agent]
# ...                                                 ...
# 3589  [Refer caller to Ministry of Highways, Works y...
# 3590  [Refer caller to Ministry of Highways, Works y...
# 3591  [Create a call, Obtain the type of investigati...
# 3592  [Create a call, Obtain the type of investigati...
# 3593  [Create a call, Obtain the type of investigati...
#
#                                              filename  cluster
# 0                                     AB - FRAUD.docx        0
# 1     AB - PROP - Property lost, found or seized.docx        0
# 2     BI - PROP - Property lost, found or seized.docx        0
# 3     BU - PROP - Property lost, found or seized.docx        0
# 4     DE - PROP - Property lost, found or seized.docx        0
# ...                                               ...      ...
# 3589                                 SX - ANIMAL.docx      188
# 3590                                 UN - ANIMAL.docx      188
# 3591            DE - ASSOA - Assist Other Agency.docx      189
# 3592            SX - ASSOA - Assist Other Agency.docx      189
# 3593            WV - ASSOA - Assist Other Agency.docx      189
#
# [3594 rows x 7 columns]

# %%
situ_topics_kmeans_tfidf['situ_lst'] = situ_topics_kmeans_tfidf['situation'].apply(lambda x: [x])

# %%
situ_topics_kmeans_tfidf.to_csv('../data/interim/situ_topics_kmeans_tfidf.csv', index = False)

# %%
# situ_clusters = situ_topics_kmeans_tfidf.groupby('cluster').agg({
#     'situation': lambda x: list(x)
# })
# situ_clusters

# %%
cluster_bow, cluster_corpus, cluster_dict = get_dct_dtmatrix(situ_topics_kmeans_tfidf['situ_lst'])

# %%
len(cluster_dict.token2id)
# Out:
# 743

# %%
tfidf_cluster = TfidfModel(cluster_bow)
tfidf_mtx_cluster = bow2tfidf(cluster_bow, tfidf_cluster)

# %%
def show_result(query_mtx, corpus_mtx, N = 20):
    sim = cosine_similarity(query_mtx, corpus_mtx)[0]
    cluster_sorted = zip(sim.argsort()[::-1], sorted(sim)[::-1])
    idx = list()
    for cnt, (i, prob) in enumerate(cluster_sorted):
        if prob < 0.1 or cnt >= N:
            break
        idx.append(i)
    return situ_topics_kmeans_tfidf.iloc[idx].copy().drop(columns = 'situ_lst')

# %%
def query_situation(query, corpus_tfidf, corpus_dct, corpus_mtx, N = 20):
    query_corpus = [preprocess([query]).split()]
    query_bow = [corpus_dct.doc2bow(doc) for doc in query_corpus]
    query_tfidf_mtx = bow2tfidf(query_bow, corpus_tfidf)
    return show_result(query_tfidf_mtx, corpus_mtx, N = N)

# %%
query = 'missing child'
query1 = 'lost passport'
query_result = query_situation(query, tfidf_cluster, cluster_dict, tfidf_mtx_cluster)
query_result
# Out:
#         type juri        role    situation  \
# 853   ASLTSX   SC  call taker  Child Abuse
# 2980    ASLT   NW  call taker  Child Abuse
# 836    ASLTI   RI  call taker  Child Abuse
# 835    ASLTI   PO  call taker  Child Abuse
# 834    ASLTI   NW  call taker  Child Abuse
# 833    ASLTI   DE  call taker  Child Abuse
# 831    ASLTI   BI  call taker  Child Abuse
# 830    ASLTI   AB  call taker  Child Abuse
# 2977    ASLT   BI  call taker  Child Abuse
# 2978    ASLT   BU  call taker  Child Abuse
# 2982    ASLT   RI  call taker  Child Abuse
# 838    ASLTI   SC  call taker  Child Abuse
# 2983    ASLT   RM  call taker  Child Abuse
# 2984    ASLT   SC  call taker  Child Abuse
# 2985    ASLT   SQ  call taker  Child Abuse
# 2986    ASLT   SX  call taker  Child Abuse
# 2987    ASLT   UN  call taker  Child Abuse
# 2988    ASLT   VA  call taker  Child Abuse
# 2989    ASLT   WP  call taker  Child Abuse
# 2990    ASLT   WV  call taker  Child Abuse
#
#                                                     sop  \
# 853   [Create a call if there is immediate risk to a...
# 2980  [Create a call, Questions, Time delay?, What a...
# 836   [When there is immediate risk to a child’s saf...
# 835   [When there is immediate risk to a child’s saf...
# 834   [When there is immediate risk to a child’s saf...
# 833   [When there is immediate risk to a child’s saf...
# 831   [When there is immediate risk to a child’s saf...
# 830   [When there is immediate risk to a child’s saf...
# 2977  [Create a call, Questions, Time delay?, What a...
# 2978  [Create a call, Questions, Time delay?, What a...
# 2982  [Create a call, Questions, Time delay?, What a...
# 838   [When there is immediate risk to a child’s saf...
# 2983  [Create a call, Questions, Time delay?, What a...
# 2984  [Create a call, Questions, Time delay?, What a...
# 2985  [Create a call, Questions, Time delay?, What a...
# 2986  [Create a call, Questions, Time delay?, What a...
# 2987  [Create a call, Questions, Time delay?, What a...
# 2988  [Create a call, Questions, Time delay?, What a...
# 2989  [Create a call, Questions, Time delay?, What a...
# 2990  [Create a call, Questions, Time delay?, What a...
#
#                                    filename  cluster
# 853       SC - ASLTSX - Sexual assault.docx       14
# 2980               NW - ASLT - Assault.docx      147
# 836   RI - ASLTI - Assault in Progress.docx       14
# 835   PO - ASLTI - Assault in Progress.docx       14
# 834   NW - ASLTI - Assault in Progress.docx       14
# 833   DE - ASLTI - Assault in Progress.docx       14
# 831   BI - ASLTI - Assault in Progress.docx       14
# 830   AB - ASLTI - Assault in Progress.docx       14
# 2977               BI - ASLT - Assault.docx      147
# 2978               BU - ASLT - Assault.docx      147
# 2982               RI - ASLT - Assault.docx      147
# 838   SC - ASLTI - Assault in Progress.docx       14
# 2983               RM - ASLT - Assault.docx      147
# 2984               SC - ASLT - Assault.docx      147
# 2985               SQ - ASLT - Assault.docx      147
# 2986               SX - ASLT - Assault.docx      147
# 2987               UN - ASLT - Assault.docx      147
# 2988               VA - ASLT - Assault.docx      147
# 2989               WP - ASLT - Assault.docx      147
# 2990               WV - ASLT - Assault.docx      147

# %%
# query = 'lost license plate'
# query_corpus = [preprocess([query]).split()]
# query_bow = [cluster_dict.doc2bow(doc) for doc in query_corpus]
# query_tfidf_mtx = bow2tfidf(query_bow, tfidf_cluster)
# sim = cosine_similarity(query_tfidf_mtx, tfidf_mtx_cluster)[0]
# cluster_sorted = zip(sim.argsort()[::-1], sorted(sim)[::-1])
# idx = list()
# for cnt, (i, prob) in enumerate(cluster_sorted):
#     if prob < 0.05 or cnt > 10:
#         break
#     idx.append(i)
# idx

# %%
# situ_topics_kmeans_tfidf.iloc[idx]

# %%
raise Exception('Stop here')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-25-b0553b8dfe68> in <module>
# ----> 1 raise Exception('Stop here')
#
# Exception: Stop here

# %%
def func1(patn, lst):
    reg = re.findall(patn, ' '.join(lst), re.IGNORECASE)
    if reg:
        return True
    else:
        return False
    
def find_srs_pattern(patn, pd_srs):
    return list(map(lambda x: func1(patn, x), pd_srs))

situ_lda_tfidf_topics[find_srs_pattern('domi', situ_lda_tfidf_topics['sop'])]
