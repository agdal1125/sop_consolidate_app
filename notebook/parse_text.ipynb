# %%
import os
import json
from docx import Document
from io import StringIO, BytesIO
import re

import pandas as pd

# %% [markdown]
# #### Define file directories

# %%
notebook_dir = os.getcwd()
sop_dir = '/Users/public/Desktop/SOPs/'
os.chdir(sop_dir)
sop_list = os.listdir('.')
len(sop_list)
# Out:
# 2021

# %% [markdown]
# #### Formulate desired jurisdictions and unwanted files

# %%
juri_list = {'AB', 'BI', 'BU', 'DE', 'DFPF', 
            'NW', 'PO', 'RI', 'RM', 'SC', 
            'SQ', 'SX', 'UN', 'VA', 'WP', 
            'WV', 'DF PF'}
exclude_docs = ['- report' # gray; non-police
                , '- drugs -' # gray; non-police
                , 'bomb threats' # red; fire-related
                , 'water problem' # red; fire-related
                , 'wildfire'
                , 'stove fire'
                , 'electrical problem'
               ]

# %%
sop_list
# Out:
# ['AB - 1033 - Officer in trouble.docx',
#  'AB - 911.docx',
#  'AB - AB911 cell.docx',
#  'AB - AB911 Landline.docx',
#  'AB - ABANDV - Abandoned vehicle.docx',
#  'AB - ABANDV - Reports.docx',
#  'AB - ABDUC - Abduction.docx',
#  'AB - AIREM - Airplane Crash.docx',
#  'AB - ALARM - Audible Alarm.docx',
#  'AB - ALARMA - Airport alarm.docx',
#  'AB - ALARMD - Domestic violence alarm.docx',
#  'AB - ALARMH - Holdup alarm.docx',
#  'AB - ALARMS - Silent or Panic Alarm.docx',
#  'AB - ANIMAL.docx',
#  'AB - ANNOY - Annoying circumstance.docx',
#  'AB - ARREST.docx',
#  'AB - ARSON.docx',
#  'AB - ASLT - Assault.docx',
#  'AB - ASLTI - Assault in Progress.docx',
#  'AB - ASLTSX - Sexual assault.docx',
#  'AB - ASSGP - Assist General Public.docx',
#  'AB - ASSMHA - Assist Mental Health Act.docx',
#  'AB - ASSOA - Assist Other Agency.docx',
#  'AB - ASSPFA - Assist Police Fire Ambulance.docx',
#  'AB - BAIT-Bait Car Activation.docx',
#  'AB - BNE - Break and Enter.docx',
#  'AB - BNEI - Break and enter in progress.docx',
#  'AB - BOMB - Bomb Threat.docx',
#  'AB - BORDR - Border Runner.docx',
#  'AB - BREACH.docx',
#  'AB - BYLAW.docx',
#  'AB - CHECK - Check wellbeing.docx',
#  'AB - COUNTERFEIT - Counterfeit Currency.docx',
#  'AB - DEMON - Demonstration.docx',
#  'AB - DISTB - Disturbance.docx',
#  'AB - DOMI - Domestic in progress.docx',
#  'AB - DOMRPT - Domestic report.docx',
#  'AB - DRUGS.docx',
#  'AB - EXPLOS  - Explosion Explosives.docx',
#  'AB - EXTORT - Extortion.docx',
#  'AB - FIGHT - Fight.docx',
#  'AB - FIREAR - Firearm for Pickup Transport.docx',
#  'AB - FOUNDP - Found Person.docx',
#  'AB - FRAUD - Reports.docx',
#  'AB - FRAUD.docx',
#  'AB - HARASS - Harassment.docx',
#  'AB - HAZARD - Hazard.docx',
#  'AB - HOMEIN - Home Invasion.docx',
#  'AB - HOSTAG - Hostage Situation.docx',
#  'AB - IMPAIR - Impaired driver.docx',
#  'AB - INDEC - Indecent Act.docx',
#  'AB - INDUST - Industrial Accident.docx',
#  'AB - INSEC - Insecure Premises Vehicle.docx',
#  'AB - INTELL - Intelligence Information.docx',
#  'AB - JUMPER.docx',
#  'AB - KPEACE - Keep the Peace.docx',
#  'AB - LIQUOR - Liquor Act Licensed Premises Check.docx',
#  'AB - MAND - Man Down.docx',
#  'AB - MARINE - Marine Incident.docx',
#  'AB - MISCH - Mischief - Reports.docx',
#  'AB - MISCH - Mischief.docx',
#  'AB - MISCHI - Mischief in Progress.docx',
#  'AB - MISSIC - Missing Child - Reports.docx',
#  'AB - MISSIC - Missing Child.docx',
#  'AB - MISSIP - Missing person - Reports.docx',
#  'AB - MISSIP - Missing person.docx',
#  'AB - MVI - Motor Vehicle Incident.docx',
#  'AB - MVIHR - Hit and Run.docx',
#  'AB - MVIINJ - Motor Vehicle Incident with injuries.docx',
#  'AB - MVIPOL - MVI with police vehicle.docx',
#  'AB - NOK - Next of kin notification.docx',
#  'AB - OCC - Other Criminal Code.docx',
#  'AB - OVERD - Overdose.docx',
#  'AB - PANHA - Panhandler.docx',
#  'AB - PARK - Parking complaint.docx',
#  'AB - PROP - Property - Reports.docx',
#  'AB - PROP - Property lost, found or seized.docx',
#  'AB - PROST.docx',
#  'AB - PROWL.docx',
#  'AB - Pursue.docx',
#  'AB - RECVEH - Recovered vehicle - Reports.docx',
#  'AB - RECVEH - Recovered vehicle.docx',
#  'AB - ROBB - Robbery.docx',
#  'AB - ROBBI - Robbery in progress.docx',
#  'AB - SCREAM - Screams heard.docx',
#  'AB - SHOPL - Shoplifter.docx',
#  'AB - SHOTS - Shots Fired Heard.docx',
#  'AB - SIP - SIPP DIPP.docx',
#  'AB - STALK - Stalking.docx',
#  'AB - SUDDEN - Sudden Death.docx',
#  'AB - SUICID - Suicidal person.docx',
#  'AB - SUSPC - Suspicious Circumstances.docx',
#  'AB - SUSPP - Suspicious person - Reports.docx',
#  'AB - SUSPP - Suspicious person.docx',
#  'AB - SUSPV - Suspicious vehicle.docx',
#  'AB - THEFT - Theft - Reports.docx',
#  'AB - THEFT.docx',
#  'AB - THEFTI - Theft in progress.docx',
#  'AB - THEFTV - Theft of Vehicle - Reports.docx',
#  'AB - THEFTV - Theft of vehicle.docx',
#  'AB - THREATS.docx',
#  'AB - TRAFF - Traffic Complaint - Reports.docx',
#  'AB - TRAFF - Traffic Complaint.docx',
#  'AB - TRAFFS - Traffic Stop.docx',
#  'AB - UNWANT - Unwanted person.docx',
#  'AB - WARRAN - Warrant.docx',
#  'AB - WEAPON.docx',
#  'AB - YOUTH.docx',
#  'BI - 1033 - Officer in trouble.docx',
#  'BI - 911.docx',
#  'BI - AB911 cell.docx',
#  'BI - AB911 Landline.docx',
#  'BI - ABANDV - Abandoned vehicle.docx',
#  'BI - ABDUC - Abduction.docx',
#  'BI - AIREM - Airplane Crash.docx',
#  'BI - ALARM - Audible Alarm.docx',
#  'BI - ALARMD - Domestic violence alarm.docx',
#  'BI - ALARMH - Holdup alarm.docx',
#  'BI - ALARMS - Silent or Panic Alarm.docx',
#  'BI - ANIMAL.docx',
#  'BI - ANNOY - Annoying circumstance.docx',
#  'BI - ARREST.docx',
#  'BI - ARSON.docx',
#  'BI - ASLT - Assault.docx',
#  'BI - ASLTI - Assault in Progress.docx',
#  'BI - ASLTSX - Sexual assault.docx',
#  'BI - ASSGP - Assist General Public.docx',
#  'BI - ASSMHA - Assist Mental Health Act.docx',
#  'BI - ASSOA - Assist Other Agency.docx',
#  'BI - ASSPFA - Assist Police Fire Ambulance.docx',
#  'BI - BAIT-Bait Car Activation.docx',
#  'BI - BNE - Break and Enter.docx',
#  'BI - BNEI - Break and enter in progress.docx',
#  'BI - BOMB - Bomb Threat.docx',
#  'BI - BREACH.docx',
#  'BI - Bylaw.docx',
#  'BI - CHECK - Check wellbeing.docx',
#  'BI - COUNTERFEIT - Counterfeit Currency.docx',
#  'BI - DEMON - Demonstration.docx',
#  'BI - DISTB - Disturbance.docx',
#  'BI - DNA - DNA collection.docx',
#  'BI - DOMI - Domestic in progress.docx',
#  'BI - DOMRPT - Domestic report.docx',
#  'BI - DRUGS - Drugs.docx',
#  'BI - DRUGS.docx',
#  'BI - EXPLOS  - Explosion Explosives.docx',
#  'BI - EXTORT - Extortion.docx',
#  'BI - FIGHT - Fight.docx',
#  'BI - FIREAR - Firearm for Pickup Transport.docx',
#  'BI - FOUNDP - Found Person.docx',
#  'BI - FRAUD.docx',
#  'BI - HARASS - Harassment.docx',
#  'BI - HAZARD - Hazard.docx',
#  'BI - HOMEIN - Home Invasion.docx',
#  'BI - HOSTAG - Hostage Situation.docx',
#  'BI - IMPAIR - Impaired driver.docx',
#  'BI - INDEC - Indecent Act.docx',
#  'BI - INDUST - Industrial Accident.docx',
#  'BI - INSEC - Insecure Premises Vehicle.docx',
#  'BI - INTELL - Intelligence Information.docx',
#  'BI - JUMPER.docx',
#  'BI - KPEACE - Keep the Peace.docx',
#  'BI - LIQUOR - Liquor Act Licensed Premises Check.docx',
#  'BI - MAND - Man down.docx',
#  'BI - MARINE - Marine Incident.docx',
#  'BI - MISCH - Mischief.docx',
#  'BI - MISCHI - Mischief in Progress.docx',
#  'BI - MISSIC - Missing Child - Reports.docx',
#  'BI - MISSIC - Missing Child.docx',
#  'BI - MISSIP - Missing person - Reports.docx',
#  'BI - MISSIP - Missing person.docx',
#  'BI - MVI - Motor Vehicle Incident.docx',
#  'BI - MVIHR - Hit and Run.docx',
#  'BI - MVIINJ - Motor Vehicle Incident with injuries.docx',
#  'BI - MVIPOL - MVI with police vehicle.docx',
#  'BI - NOK - Next of kin notification.docx',
#  'BI - OCC - Other Criminal Code.docx',
#  'BI - OVERD - Overdose.docx',
#  'BI - PANHA - Panhandler.docx',
#  'BI - PARK - Parking complaint.docx',
#  'BI - PROP - Property - Reports.docx',
#  'BI - PROP - Property lost, found or seized.docx',
#  'BI - PROST.docx',
#  'BI - PROWL.docx',
#  'BI - Pursue.docx',
#  'BI - R - RECVEH - Recovered vehicle.docx',
#  'BI - R - SUSPP - Suspicious person.docx',
#  'BI - RECVEH - Recovered vehicle.docx',
#  'BI - ROBB - Robbery.docx',
#  'BI - ROBBI - Robbery in progress.docx',
#  'BI - SCREAM - Screams heard.docx',
#  'BI - SHOPL - Shoplifter.docx',
#  'BI - SHOTS - Shots Fired Heard.docx',
#  'BI - SIP - SIPP DIPP.docx',
#  'BI - SPAT - Special Attention Detail Event.docx',
#  'BI - STALK - Stalking.docx',
#  'BI - SUDDEN - Sudden Death.docx',
#  'BI - SUICID - Suicidal person.docx',
#  'BI - SUSPC - Suspicious Circumstances.docx',
#  'BI - SUSPP - Suspicious person.docx',
#  'BI - SUSPV - Suspicious vehicle.docx',
#  'BI - THEFT - Theft - Reports.docx',
#  'BI - THEFT.docx',
#  'BI - THEFTI - Theft in progress.docx',
#  'BI - THEFTV - Theft of Vehicle - Reports.docx',
#  'BI - THEFTV - Theft of vehicle.docx',
#  'BI - THREATS.docx',
#  'BI - TRAFF - Traffic Complaint.docx',
#  'BI - TRAFFS - Traffic Stop.docx',
#  'BI - UNWANT - Unwanted person.docx',
#  'BI - WARRAN - Warrant.docx',
#  'BI - WEAPON.docx',
#  'BI - YOUTH.docx',
#  'BU - 1033 - Officer in trouble.docx',
#  'BU - 911.docx',
#  'BU - AB911 cell.docx',
#  'BU - AB911 Landline.docx',
#  'BU - ABANDV - Abandoned vehicle.docx',
#  'BU - ABDUC - Abduction.docx',
#  'BU - AIREM - Airplane Crash.docx',
#  'BU - ALARM - Audible Alarm.docx',
#  'BU - ALARMD - Domestic violence alarm.docx',
#  'BU - ALARMH - Holdup alarm.docx',
#  'BU - ALARMS - Silent or Panic Alarm.docx',
#  'BU - ANIMAL.docx',
#  'BU - ANNOY - Annoying circumstance.docx',
#  'BU - ARREST.docx',
#  'BU - ARSON.docx',
#  'BU - ASLT - Assault.docx',
#  'BU - ASLTI - Assault in Progress.docx',
#  'BU - ASLTSX - Sexual assault.docx',
#  'BU - ASSGP - Assist General Public.docx',
#  'BU - ASSMHA - Assist Mental Health Act.docx',
#  'BU - ASSOA - Assist Other Agency.docx',
#  'BU - ASSPFA - Assist Police Fire Ambulance.docx',
#  'BU - BAIT-Bait Car Activation.docx',
#  'BU - BNE - Break and Enter.docx',
#  'BU - BNEI - Break and enter in progress.docx',
#  'BU - BOMB - Bomb Threat.docx',
#  'BU - BREACH.docx',
#  'BU - Bylaw.docx',
#  'BU - CHECK - Check wellbeing.docx',
#  'BU - COUNTERFEIT - Counterfeit Currency.docx',
#  'BU - DEMON - Demonstration.docx',
#  'BU - DISTB - Disturbance.docx',
#  'BU - DNA - DNA collection.docx',
#  'BU - DOMI - Domestic in progress.docx',
#  'BU - DOMRPT - Domestic report.docx',
#  'BU - DRUGS - Drugs.docx',
#  'BU - DRUGS.docx',
#  'BU - EXPLOS  - Explosion Explosives.docx.docx',
#  'BU - EXTORT - Extortion.docx',
#  'BU - FIGHT - Fight.docx',
#  'BU - FIREAR - Firearm for Pickup Transport.docx',
#  'BU - FOUNDP - Found Person.docx',
#  'BU - FRAUD.docx',
#  'BU - HARASS - Harassment.docx',
#  'BU - HAZARD - Hazard.docx',
#  'BU - HOMEIN - Home Invasion.docx',
#  'BU - HOSTAG - Hostage Situation.docx',
#  'BU - IMPAIR - Impaired driver.docx',
#  'BU - INDEC - Indecent Act.docx',
#  'BU - INDUST - Industrial Accident.docx',
#  'BU - INSEC - Insecure Premises Vehicle.docx',
#  'BU - INTELL - Intelligence Information.docx',
#  'BU - JUMPER.docx',
#  'BU - KPEACE - Keep the Peace.docx',
#  'BU - LIQUOR - Liquor Act Licensed Premises Check.docx',
#  'BU - MAND - Man Down.docx',
#  'BU - MARINE - Marine Incident.docx',
#  'BU - MISCH - Mischief - Reports.docx',
#  'BU - MISCH - Mischief.docx',
#  'BU - MISCHI - Mischief in Progress.docx',
#  'BU - MISSIC - Missing Child - Reports.docx',
#  'BU - MISSIC - Missing Child.docx',
#  'BU - MISSIP - Missing person - Reports.docx',
#  'BU - MISSIP - Missing person.docx',
#  'BU - MVI - Motor vehicle incident.docx',
#  'BU - MVIHR - Motor vehicle hit and run.docx',
#  'BU - MVIINJ - Motor Vehicle Incident with injuries.docx',
#  'BU - MVIPOL - MVI with police vehicle.docx',
#  'BU - NOK - Next of kin notification.docx',
#  'BU - OCC - Other Criminal Code.docx',
#  'BU - OVERD - Overdose.docx',
#  'BU - PANHA - Panhandler.docx',
#  'BU - PARK - Parking complaint.docx',
#  'BU - PROP - Property - Reports.docx',
#  'BU - PROP - Property lost, found or seized.docx',
#  'BU - PROST.docx',
#  'BU - PROWL.docx',
#  'BU - Pursue.docx',
#  'BU - R - RECVEH - Recovered vehicle.docx',
#  'BU - R - SUSPP - Suspicious person.docx',
#  'BU - RECVEH - Recovered vehicle.docx',
#  'BU - ROBB - Robbery.docx',
#  'BU - ROBBI - Robbery in progress.docx',
#  'BU - SCREAM - Screams heard.docx',
#  'BU - SHOPL - Shoplifter.docx',
#  'BU - SHOTS - Shots Fired Heard.docx',
#  'BU - SIP - SIPP DIPP.docx',
#  'BU - SPAT - Special Attention Detail Event.docx',
#  'BU - STALK - Stalking.docx',
#  'BU - SUDDEN - Sudden Death.docx',
#  'BU - SUICID - Suicidal person.docx',
#  'BU - SUSPC - Suspicious Circumstances.docx',
#  'BU - SUSPP - Suspicious person.docx',
#  'BU - SUSPV - Suspicious vehicle.docx',
#  'BU - THEFT - Theft - Reports.docx',
#  'BU - Theft.docx',
#  'BU - THEFTI - Theft in progress.docx',
#  'BU - THEFTV - Theft of Vehicle - Reports.docx',
#  'BU - THEFTV - Theft of vehicle.docx',
#  'BU - THREATS.docx',
#  'BU - TRAFF - Traffic Complaint.docx',
#  'BU - TRAFFS - Traffic Stop.docx',
#  'BU - UNWANT - Unwanted person.docx',
#  'BU - WARRAN - Warrant.docx',
#  'BU - WEAPON.docx',
#  'BU - YOUTH.docx',
#  'CO - ACEM - Aircraft Emergency Landing.docx',
#  'CO - ACF - Aircraft Fire.docx',
#  'CO - ACRA - Airplane Crash.docx',
#  'CO - ALRM123 - Fire Alarm.docx',
#  'CO - ASIST - Calls for assistance.docx',
#  'CO - BBQF.docx',
#  'CO - BOMB - Bomb threats.docx',
#  'CO - CHIM - Chimney Fire.docx',
#  'CO - ELEC12 - Electrical problem.docx',
#  'CO - EXP123 - Explosion.docx',
#  'CO - HAZM123 - Hazardous Materials.docx',
#  'CO - ILBRN - Illegal Burn.docx',
#  'CO - MED12A - Medical aid.docx',
#  'CO - MUAID - Mutual aid.docx',
#  'CO - MVI12345 - Motor Vehicle Incident.docx',
#  'CO - ODOUU - Odour unknown source.docx',
#  'CO - POLE - Pole fire.docx',
#  'CO - PREV - Fire Prevention.docx',
#  'CO - RES123M - Rescue calls.docx',
#  'CO - RUBSH - Rubbish fire.docx',
#  'CO - SCOB - Single company, unit response.docx',
#  'CO - SCOLL - Structure collapse.docx',
#  'CO - SHIP123 - Ship fire.docx',
#  'CO - SMK123 - Report of smoke.docx',
#  'CO - ST123 - Structure fire.docx',
#  'CO - STOVE - Stove fire.docx',
#  'CO - TEST - Test call.docx',
#  'CO - VAULT.docx',
#  'CO - VEF123 - Vehicle fire.docx',
#  'CO - WATER - Water problem.docx',
#  'CO - WILD123 - Wildfire reported.docx',
#  'CO - WIRE12 - Wires down.docx',
#  'DE - 1033 - Officer in trouble.docx',
#  'DE - 911.docx',
#  'DE - AB911 cell.docx',
#  'DE - AB911 Landline.docx',
#  'DE - ABANDV - Abandoned vehicle.docx',
#  'DE - ABDUC - Abduction.docx',
#  'DE - ACF - Aircraft Fire.docx',
#  'DE - ACRA - Airplane Crash.docx',
#  'DE - AIREM - Airplane Crash.docx',
#  'DE - ALARM - Audible Alarm.docx',
#  'DE - ALARMD - Domestic violence alarm.docx',
#  'DE - ALARMH - Holdup alarm.docx',
#  'DE - ALARMS - Silent or Panic Alarm.docx',
#  'DE - ALRM123 - Fire Alarm.docx',
#  'DE - ANIMAL.docx',
#  'DE - ANNOY - Annoying circumstance.docx',
#  'DE - ARREST.docx',
#  'DE - ARSON.docx',
#  'DE - ASIST - Calls for assistance.docx',
#  'DE - ASLT - Assault.docx',
#  'DE - ASLTI - Assault in Progress.docx',
#  'DE - ASLTSX - Sexual assault.docx',
#  'DE - ASSGP - Assist General Public.docx',
#  'DE - ASSMHA - Assist Mental Health Act.docx',
#  'DE - ASSOA - Assist Other Agency.docx',
#  'DE - ASSPFA - Assist Police Fire Ambulance.docx',
#  'DE - BAIT-Bait Car Activation.docx',
#  'DE - BBQF.docx',
#  'DE - BNE - Break and Enter.docx',
#  'DE - BNEI - Break and enter in progress.docx',
#  'DE - BOMB - Bomb Threat.docx',
#  'DE - BOMB - Bomb threats.docx',
#  'DE - BORDR - Border Runner.docx',
#  'DE - BREACH.docx',
#  'DE - BYLAW.docx',
#  'DE - CHECK - Check wellbeing.docx',
#  'DE - CHIM - Chimney Fire.docx',
#  'DE - COUNTERFEIT - Counterfeit Currency.docx',
#  'DE - DEMON - Demonstration.docx',
#  'DE - DISTB - Disturbance.docx',
#  'DE - DNA - DNA collection.docx',
#  'DE - DOMI - Domestic in progress.docx',
#  'DE - DOMRPT - Domestic report.docx',
#  'DE - DRUGS - Drugs.docx',
#  'DE - DRUGS.docx',
#  'DE - ELEC12 - Electrical problem.docx',
#  'DE - EXP123 - Explosion.docx',
#  'DE - EXPLOS  - Explosion Explosives.docx',
#  'DE - EXTORT - Extortion.docx',
#  'DE - FIGHT - Fight.docx',
#  'DE - FIREAR - Firearm for Pickup Transport.docx',
#  'DE - FOUNDP - Found Person.docx',
#  'DE - FRAUD.docx',
#  'DE - GAS1234 - CompressedGasLeak.docx',
#  'DE - HARASS - Harassment.docx',
#  'DE - HAZARD - Hazard.docx',
#  'DE - HAZM123 - Hazardous Materials.docx',
#  'DE - HOMEIN - Home Invasion.docx',
#  'DE - HOSTAG - Hostage Situation.docx',
#  'DE - ILBRN - Illegal Burn.docx',
#  'DE - IMPAIR - Impaired driver.docx',
#  'DE - INDEC - Indecent Act.docx',
#  'DE - INDUST - Industrial Accident.docx',
#  'DE - INSEC - Insecure Premises Vehicle.docx',
#  'DE - INTELL - Intelligence Information.docx',
#  'DE - JUMPER.docx',
#  'DE - KPEACE - Keep the Peace.docx',
#  'DE - LIQUOR - Liquor Act Licensed Premises Check.docx',
#  'DE - MAND - Man Down.docx',
#  'DE - MARINE - Marine Incident.docx',
#  'DE - MED12A - Medical aid.docx',
#  'DE - MISCH - Mischief.docx',
#  'DE - MISCHI - Mischief in Progress.docx',
#  'DE - MISSIC - Missing Child - Reports.docx',
#  'DE - MISSIC - Missing Child.docx',
#  'DE - MISSIP - Missing person - Reports.docx',
#  'DE - MISSIP - Missing person.docx',
#  'DE - MUAID - Mutual aid.docx',
#  'DE - MVI - Motor Vehicle Incident.docx',
#  'DE - MVI12345 - Motor Vehicle Incident.docx',
#  'DE - MVIHR - Hit and Run.docx',
#  'DE - MVIINJ - Motor Vehicle Incident with injuries.docx',
#  'DE - MVIPOL - MVI with police vehicle.docx',
#  'DE - NOK - Next of kin notification.docx',
#  'DE - OCC - Other Criminal Code.docx',
#  'DE - ODOUU - Odour unknown source.docx',
#  'DE - OVERD - Overdose.docx',
#  'DE - PANHA - Panhandler.docx',
#  'DE - PARK - Parking complaint.docx',
#  'DE - POLE - Pole fire.docx',
#  'DE - PREV - Fire Prevention.docx',
#  'DE - PROP - Property - Reports.docx',
#  'DE - PROP - Property lost, found or seized.docx',
#  'DE - PROST.docx',
#  'DE - PROWL.docx',
#  'DE - Pursue.docx',
#  'DE - R - RECVEH - Recovered vehicle.docx',
#  'DE - R - SUSPP - Suspicious person.docx',
#  'DE - RECVEH - Recovered vehicle.docx',
#  'DE - RES123M - Rescue calls.docx',
#  'DE - ROBB - Robbery.docx',
#  'DE - ROBBI - Robbery in progress.docx',
#  'DE - RUBSH - Rubbish fire.docx',
#  'DE - SCOB - Single company, unit response.docx',
#  'DE - SCOLL - Structure collapse.docx',
#  'DE - SCREAM - Screams heard.docx',
#  'DE - SHIP123 - Ship fire.docx',
#  'DE - SHOPL - Shoplifter.docx',
#  'DE - SHOTS - Shots Fired Heard.docx',
#  'DE - SIP - SIPP DIPP.docx',
#  'DE - SMK123 - Report of smoke.docx',
#  'DE - SPAT - Special Attention Detail Event.docx',
#  'DE - ST123 - Structure fire.docx',
#  'DE - STALK - Stalking.docx',
#  'DE - STOVE - Stove fire.docx',
#  'DE - SUDDEN - Sudden Death.docx',
#  'DE - SUICID - Suicidal person.docx',
#  'DE - SUSPC - Suspicious Circumstances.docx',
#  'DE - SUSPP - Suspicious person.docx',
#  'DE - SUSPV - Suspicious vehicle.docx',
#  'DE - TEST - Test call.docx',
#  'DE - THEFT - Theft - Reports.docx',
#  'DE - THEFT.docx',
#  'DE - THEFTI - Theft in progress.docx',
#  'DE - THEFTV - Theft of Vehicle - Reports.docx',
#  'DE - THEFTV - Theft of vehicle.docx',
#  'DE - THREATS.docx',
#  'DE - TRAFF - Traffic Complaint.docx',
#  'DE - TRAFFS - Traffic Stop.docx',
#  'DE - UNWANT - Unwanted person.docx',
#  'DE - VAULT.docx',
#  'DE - VEF123 - Vehicle fire.docx',
#  'DE - WARRAN - Warrant.docx',
#  'DE - WATER - Water problem.docx',
#  'DE - WEAPON.docx',
#  'DE - WILD123 - Wildfire reported.docx',
#  'DE - WIRE12 - Wires down.docx',
#  'DE - YOUTH.docx',
#  'DF PF - ASSPFA - Assist Police Fire Ambulance.docx',
#  'DF PF - THEFTV - Theft of Vehicle - Reports.docx',
#  'DFPF - 1033 - Officer in trouble.docx',
#  'DFPF - 911.docx',
#  'DFPF - ABANDV - Abandoned vehicle.docx',
#  'DFPF - ANIMAL.docx',
#  'DFPF - ARREST.docx',
#  'DFPF - ASSOA - Assist Other Agency.docx',
#  'DFPF - DOMI - Domestic in progress.docx',
#  'DFPF - DRUGS.docx',
#  'DFPF - FOUNDP - Found Person.docx',
#  'DFPF - HAZARD - Hazard.docx',
#  'DFPF - IMPAIR - Impaired driver.docx',
#  'DFPF - INSEC - Insecure Premises Vehicle.docx',
#  'DFPF - INTELL - Intelligence Information.docx',
#  'DFPF - JUMPER.docx',
#  'DFPF - MAND - Man Down.docx',
#  'DFPF - MISCH - Mischief.docx',
#  'DFPF - MISCHI - Mischief in Progress.docx',
#  'DFPF - MVI - Motor Vehicle Incident.docx',
#  'DFPF - MVIHR - Hit and Run.docx',
#  'DFPF - MVIINJ - Motor Vehicle Incident with injuries.docx',
#  'DFPF - MVIPOL - MVI with police vehicle.docx',
#  'DFPF - OCC - Other Criminal Code.docx',
#  'DFPF - PANHA - Panhandler.docx',
#  'DFPF - PARK - Parking complaint.docx',
#  'DFPF - PROP - Property lost, found or seized.docx',
#  'DFPF - Pursue.docx',
#  'DFPF - R - SUSPP - Suspicious person.docx',
#  'DFPF - RECVEH - Recovered vehicle.docx',
#  'DFPF - SCREAM - Screams heard.docx',
#  'DFPF - SHOTS - Shots Fired Heard.docx',
#  'DFPF - SIP - SIPP DIPP.docx',
#  'DFPF - SUDDEN - Sudden Death.docx',
#  'DFPF - SUICID - Suicidal person.docx',
#  'DFPF - SUSPC - Suspicious Circumstances.docx',
#  'DFPF - SUSPP - Suspicious person.docx',
#  'DFPF - SUSPV - Suspicious vehicle.docx',
#  'DFPF - THEFTV - Theft of vehicle.docx',
#  'DFPF - TRAFF - Traffic Complaint.docx',
#  'DFPF - TRAFFS - Traffic Stop.docx',
#  'DFPF - WEAPON.docx',
#  'ECVI -  AB911 Abandoned 911 Landline.docx',
#  'ECVI -  ANIMAL Animal - VI.docx',
#  'ECVI - 1033 Officer in trouble.docx',
#  'ECVI - 911 Police - Any Call.docx',
#  'ECVI - AB911 Abandoned 911 Cell.docx',
#  'ECVI - ABANDV - Abandoned vehicle.docx',
#  'ECVI - ABDUC Abduction.docx',
#  'ECVI - AIREM Air Emergency.docx',
#  'ECVI - ALARM Alarm.docx',
#  'ECVI - ALARMA Alarm Airport Check Point.docx',
#  'ECVI - ALARMD Alarm DVERS.docx',
#  'ECVI - ALARMH Alarm Hold Up.docx',
#  'ECVI - ALARMS Alarm Silent Panic.docx',
#  'ECVI - ANIMAL Animal - OB.docx',
#  'ECVI - ANIMAL Animal - SA.docx',
#  'ECVI - ANIMAL Animal - VI RCMP.docx',
#  'ECVI - ANNOY Annoying Circumstances.docx',
#  'ECVI - ARREST Arrest.docx',
#  'ECVI - ARSON Arson.docx',
#  'ECVI - ASLT Assault.docx',
#  'ECVI - ASLTI Assault In Progress.docx',
#  'ECVI - ASLTSX Assault Sexual.docx',
#  'ECVI - ASSGP Assist General Public.docx',
#  'ECVI - ASSMHA Assist Mental Health Act.docx',
#  'ECVI - ASSOA Assist Other Agency.docx',
#  'ECVI - ASSPFA Assist Police Fire Ambulance.docx',
#  'ECVI - BAIT Bait Car Activated.docx',
#  'ECVI - BNE Break And Enter.docx',
#  'ECVI - BNEI Break And Enter In Progress.docx',
#  'ECVI - BOMB Bomb Threat.docx',
#  'ECVI - BORDR Border Runner - VI.docx',
#  'ECVI - BREACH Breach.docx',
#  'ECVI - BYLAW Bylaw - SA.docx',
#  'ECVI - BYLAW Bylaw - VI RCMP.docx',
#  'ECVI - BYLAW Bylaw - VI.docx',
#  'ECVI - CHECK Check Wellbeing.docx',
#  'ECVI - COUNT Counterfeit Currency.docx',
#  'ECVI - DEMON Demonstration Protest.docx',
#  'ECVI - DISTB Disturbance.docx',
#  'ECVI - DNA DNA Collection.docx',
#  'ECVI - DOMI Domestic In Progress.docx',
#  'ECVI - DOMRPT Domestic Report.docx',
#  'ECVI - DRUGS Drugs.docx',
#  'ECVI - EXPLOS Explosives.docx',
#  'ECVI - EXTORT Extortion.docx',
#  'ECVI - FIGHT Fight.docx',
#  'ECVI - FIREAR Firearms For Pickup Transport.docx',
#  'ECVI - FOUNDP Found Person.docx',
#  'ECVI - FRAUD Fraud.docx',
#  'ECVI - HARASS Harassment.docx',
#  'ECVI - HAZARD Hazardous Situation.docx',
#  'ECVI - HOMEIN Home Invasion.docx',
#  'ECVI - HOSTAG Hostage.docx',
#  'ECVI - IMPAIR Impaired.docx',
#  'ECVI - INDEC Indecent Act.docx',
#  'ECVI - INDUST Industrial Accident.docx',
#  'ECVI - INSEC Insecure Premises Or Vehicle.docx',
#  'ECVI - INTELL Intelligence Information.docx',
#  'ECVI - JUMPER Jumper.docx',
#  'ECVI - KPEACE Keep The Peace.docx',
#  'ECVI - LIQUOR Liquor Act Licensed Premises Check.docx',
#  'ECVI - MAND Man Down.docx',
#  'ECVI - MARINE Marine Incident.docx',
#  'ECVI - MISCH Mischief.docx',
#  'ECVI - MISCHI Mischief In Progress.docx',
#  'ECVI - MISSIC Missing Child.docx',
#  'ECVI - MISSIP Missing Person.docx',
#  'ECVI - MVI MVI.docx',
#  'ECVI - MVIHR MVI Hit And Run - SA.docx',
#  'ECVI - MVIHR MVI Hit And Run - VI RCMP.docx',
#  'ECVI - MVIHR MVI Hit And Run - VI.docx',
#  'ECVI - MVIINJ MVI Injury.docx',
#  'ECVI - MVIPOL MVI Police Vehicle.docx',
#  'ECVI - NOK Next Of Kin Notification.docx',
#  'ECVI - OCC Other Criminal Code.docx',
#  'ECVI - OVERD Overdose.docx',
#  'ECVI - PANHA Panhandler.docx',
#  'ECVI - PARK Parking - SA.docx',
#  'ECVI - PARK Parking - VI RCMP.docx',
#  'ECVI - PARK Parking - VI.docx',
#  'ECVI - PROP Property.docx',
#  'ECVI - PROST Prostitution.docx',
#  'ECVI - PROWL Prowler.docx',
#  'ECVI - PURSUE Pursuit.docx',
#  'ECVI - RECVEH Recovered Vehicle.docx',
#  'ECVI - ROBB Robbery.docx',
#  'ECVI - ROBBI Robbery In Progress.docx',
#  'ECVI - SCREAM Scream.docx',
#  'ECVI - SHOPL Shoplifter.docx',
#  'ECVI - SHOTS Shots Fired Heard.docx',
#  'ECVI - SIP SIPP DIPP.docx',
#  'ECVI - SPAT Special Attention Detail Event.docx',
#  'ECVI - STALK Stalking.docx',
#  'ECVI - SUDDEN Sudden Death.docx',
#  'ECVI - SUICID Suicidal Person.docx',
#  'ECVI - SUSPC Suspicious Circumstances.docx',
#  'ECVI - SUSPP Suspicious Person.docx',
#  'ECVI - SUSPV Suspicious Vehicle.docx',
#  'ECVI - THEFT Theft.docx',
#  'ECVI - THEFTI Theft In Progress.docx',
#  'ECVI - THEFTV Theft Of Vehicle.docx',
#  'ECVI - THREATS Threats.docx',
#  'ECVI - TRAFF Traffic Incident.docx',
#  'ECVI - TRAFFS Traffic Suspension 24 HR 12 HR Prohib Notice.docx',
#  'ECVI - UNWANT Unwanted Person.docx',
#  'ECVI - WARRAN Warrant.docx',
#  'ECVI - WEAPON Weapon.docx',
#  'ECVI - YOUTH Youth.docx',
#  'FVRD  RDNO -  ACF - Aircraft Fire.docx',
#  'FVRD  RDNO -  ACRA - Airplane Crash.docx',
#  'FVRD  RDNO -  ALRM123 - Fire Alarm.docx',
#  'FVRD  RDNO -  ASIST - Calls for assistance.docx',
#  'FVRD  RDNO -  BBQF.docx',
#  'FVRD  RDNO -  BOMB - Bomb threats.docx',
#  'FVRD  RDNO -  CHIM - Chimney Fire.docx',
#  'FVRD  RDNO -  ELEC12 - Electrical problem.docx',
#  'FVRD  RDNO -  EXP123 - Explosion.docx',
#  'FVRD  RDNO -  GAS1234 - CompressedGasLeak.docx',
#  'FVRD  RDNO -  HAZM123 - Hazardous Materials.docx',
#  'FVRD  RDNO -  ILBRN - Illegal Burn.docx',
#  'FVRD  RDNO -  MED12A - Medical aid.docx',
#  'FVRD  RDNO -  MUAID - Mutual aid.docx',
#  'FVRD  RDNO -  MVI12345 - Motor Vehicle Incident.docx',
#  'FVRD  RDNO -  ODOUU - Odour unknown source.docx',
#  'FVRD  RDNO -  POLE - Pole fire.docx',
#  'FVRD  RDNO -  PREV - Fire Prevention.docx',
#  'FVRD  RDNO -  RES123M - Rescue calls.docx',
#  'FVRD  RDNO -  RUBSH - Rubbish fire.docx',
#  'FVRD  RDNO -  SCOB - Single company, unit response.docx',
#  'FVRD  RDNO -  SCOLL - Structure collapse.docx',
#  'FVRD  RDNO -  SHIP123 - Ship fire.docx',
#  'FVRD  RDNO -  SMK123 - Report of smoke.docx',
#  'FVRD  RDNO -  ST123 - Structure fire.docx',
#  'FVRD  RDNO -  STOVE - Stove fire.docx',
#  'FVRD  RDNO -  TEST - Test call.docx',
#  'FVRD  RDNO -  VAULT.docx',
#  'FVRD  RDNO -  VEF123 - Vehicle fire.docx',
#  'FVRD  RDNO -  WILD123 - Wildfire reported.docx',
#  'FVRD  RDNO -  WIRE12 - Wires down.docx',
#  'FVRD  RDNO - MUNI - Municipal aid.docx',
#  'FVRD RDNO - STAFF - Core staffing.docx',
#  'NW - 1033 - Officer in trouble.docx',
#  'NW - 911.docx',
#  'NW - AB911 cell.docx',
#  'NW - AB911 Landline.docx',
#  'NW - ABANDV - Abandoned vehicle.docx',
#  'NW - ABDUC - Abduction.docx',
#  'NW - ACF - Aircraft Fire.docx',
#  'NW - ACRA - Airplane Crash.docx',
#  'NW - AIREM - Airplane Crash.docx',
#  'NW - ALARM - Audible Alarm.docx',
#  'NW - ALARMD - Domestic violence alarm.docx',
#  'NW - ALARMH - Holdup alarm.docx',
#  'NW - ALARMS - Silent or Panic Alarm.docx',
#  'NW - ALRM123 - Fire Alarm.docx',
#  'NW - ANIMAL.docx',
#  'NW - ANNOY - Annoying circumstance.docx',
#  'NW - ARREST.docx',
#  'NW - ARSON.docx',
#  'NW - ASIST - Calls for assistance.docx',
#  'NW - ASLT - Assault.docx',
#  'NW - ASLTI - Assault in Progress.docx',
#  'NW - ASLTSX - Sexual assault.docx',
#  'NW - ASSGP - Assist General Public.docx',
#  'NW - ASSMHA - Assist Mental Health Act.docx',
#  'NW - ASSOA - Assist Other Agency.docx',
#  'NW - ASSPFA - Assist Police Fire Ambulance.docx',
#  'NW - BAIT-Bait Car Activation.docx',
#  'NW - BBQF.docx',
#  'NW - BNE - Break and Enter.docx',
#  'NW - BNEI - Break and enter in progress.docx',
#  'NW - BOMB - Bomb Threat.docx',
#  'NW - BOMB - Bomb threats.docx',
#  'NW - BREACH.docx',
#  'NW - Bylaw.docx',
#  'NW - CHECK - Check wellbeing.docx',
#  'NW - CHIM - Chimney Fire.docx',
#  'NW - COUNTERFEIT - Counterfeit Currency.docx',
#  'NW - DEMON - Demonstration.docx',
#  'NW - DISTB - Disturbance.docx',
#  'NW - DNA - DNA collection .docx',
#  'NW - DOMI - Domestic in progress.docx',
#  'NW - DOMRPT - Domestic report.docx',
#  'NW - DRUGS - Drugs.docx',
#  'NW - DRUGS.docx',
#  'NW - ELEC12.docx',
#  'NW - EXP123 - Explosion.docx',
#  'NW - EXPLOS  - Explosion Explosives.docx.docx',
#  'NW - EXTORT - Extortion.docx',
#  'NW - FIGHT - Fight.docx',
#  'NW - FIREAR - Firearm for Pickup Transport.docx',
#  'NW - FOUNDP - Found Person.docx',
#  'NW - FRAUD.docx',
#  'NW - GAS1234 - CompressedGasLeak.docx',
#  'NW - HARASS - Harassment.docx',
#  'NW - HAZARD - Hazard.docx',
#  'NW - HAZM123 - Hazardous Materials.docx',
#  'NW - HOMEIN - Home Invasion.docx',
#  'NW - HOSTAG - Hostage Situation.docx',
#  'NW - ILBRN - Illegal Burn.docx',
#  'NW - IMPAIR - Impaired driver.docx',
#  'NW - INDEC - Indecent Act.docx',
#  'NW - INDUST - Industrial Accident.docx',
#  'NW - INSEC - Insecure Premises Vehicle.docx',
#  'NW - INTELL - Intelligence Information.docx',
#  'NW - JUMPER.docx',
#  'NW - KPEACE - Keep the Peace.docx',
#  'NW - LIQUOR - Liquor Act Licensed Premises Check.docx',
#  'NW - MAND - Man Down.docx',
#  'NW - MARINE - Marine Incident.docx',
#  'NW - MED12A - Medical aid.docx',
#  'NW - MISCH - Mischief.docx',
#  'NW - MISCHI - Mischief in Progress.docx',
#  'NW - MISSIC - Missing Child - Reports.docx',
#  'NW - MISSIC - Missing Child.docx',
#  'NW - MISSIP - Missing person - Reports.docx',
#  'NW - MISSIP - Missing person.docx',
#  'NW - MUAID - Mutual aid.docx',
#  'NW - MVI - Motor Vehicle Incident.docx',
#  'NW - MVI12345 - Motor Vehicle Incident.docx',
#  'NW - MVIHR - Hit and Run.docx',
#  'NW - MVIINJ - Motor Vehicle Incident with injuries.docx',
#  'NW - MVIPOL - MVI with police vehicle.docx',
#  'NW - NOK - Next of kin notification.docx',
#  'NW - OCC - Other Criminal Code.docx',
#  'NW - ODOUU - Odour unknown source.docx',
#  'NW - OVERD - Overdose.docx',
#  'NW - PANHA - Panhandler.docx',
#  'NW - PARK - Parking complaint.docx',
#  'NW - POLE - Pole fire.docx',
#  'NW - PREV - Fire Prevention.docx',
#  'NW - PROP - Property - Reports.docx',
#  'NW - PROP - Property lost, found or seized.docx',
#  'NW - PROST.docx',
#  'NW - PROWL.docx',
#  'NW - Pursue.docx',
#  'NW - R - RECVEH - Recovered vehicle.docx',
#  'NW - R - SUSPP - Suspicious person.docx',
#  'NW - RECVEH - Recovered vehicle.docx',
#  'NW - RES123M - Rescue calls.docx',
#  'NW - ROBB - Robbery.docx',
#  'NW - ROBBI - Robbery in progress.docx',
#  'NW - RUBSH - Rubbish fire.docx',
#  'NW - SCOB - Single company, unit response.docx',
#  'NW - SCOLL - Structure collapse.docx',
#  'NW - SCREAM - Screams heard.docx',
#  'NW - SHIP123 - Ship fire.docx',
#  'NW - SHOPL - Shoplifter.docx',
#  'NW - SHOTS - Shots Fired Heard.docx',
#  'NW - SIP - SIPP DIPP.docx',
#  'NW - SMK123 - Report of smoke.docx',
#  'NW - SPAT - Special Attention Detail Event.docx',
#  'NW - ST123 - Structure fire.docx',
#  'NW - STALK - Stalking.docx',
#  'NW - STOVE - Stove fire.docx',
#  'NW - SUDDEN - Sudden Death.docx',
#  'NW - SUICID - Suicidal person.docx',
#  'NW - SUSPC - Suspicious Circumstances.docx',
#  'NW - SUSPP - Suspicious person.docx',
#  'NW - SUSPV - Suspicious vehicle.docx',
#  'NW - TEST - Test call.docx',
#  'NW - THEFT - Theft - Reports.docx',
#  'NW - THEFT.docx',
#  'NW - THEFTI - Theft in progress.docx',
#  'NW - THEFTV - Theft of Vehicle - Reports.docx',
#  'NW - THEFTV - Theft of vehicle.docx',
#  'NW - THREATS.docx',
#  'NW - TRAFF - Traffic Complaint.docx',
#  'NW - TRAFFS - Traffic Stop.docx',
#  'NW - UNWANT - Unwanted person.docx',
#  'NW - VAULT.docx',
#  'NW - VEF123 - Vehicle fire .docx',
#  'NW - WARRAN - Warrant.docx',
#  'NW - WATER - Water problem.docx',
#  'NW - WEAPON.docx',
#  'NW - WILD123 - Wildfire reported.docx',
#  'NW - WIRE12 - Wires down.docx',
#  'NW - YOUTH.docx',
#  'PO - 1033 - Officer in trouble.docx',
#  'PO - 911.docx',
#  'PO - AB911 cell.docx',
#  'PO - AB911 Landline.docx',
#  'PO - ABANDV - Abandoned vehicle.docx',
#  'PO - ABDUC - Abduction.docx',
#  'PO - ACF - Aircraft Fire.docx',
#  'PO - ACRA - Airplane Crash.docx',
#  'PO - AIREM - Airplane Crash.docx',
#  'PO - ALARM - Audible Alarm.docx',
#  'PO - ALARMD - Domestic violence alarm.docx',
#  'PO - ALARMH - Holdup alarm.docx',
#  'PO - ALARMS - Silent or Panic Alarm.docx',
#  'PO - ALRM123 - Fire Alarm.docx',
#  'PO - ANIMAL.docx',
#  'PO - ANNOY - Annoying circumstance.docx',
#  'PO - ARREST.docx',
#  'PO - ARSON.docx',
#  'PO - ASIST - Calls for assistance.docx',
#  'PO - ASLT - Assault.docx',
#  'PO - ASLTI - Assault in Progress.docx',
#  'PO - ASLTSX - Sexual assault.docx',
#  'PO - ASSGP - Assist General Public.docx',
#  'PO - ASSMHA - Assist Mental Health Act .docx',
#  'PO - ASSOA - Assist Other Agency.docx',
#  'PO - ASSPFA - Assist Police Fire Ambulance.docx',
#  'PO - BAIT-Bait Car Activation.docx',
#  'PO - BBQF.docx',
#  'PO - BNE - Break and Enter.docx',
#  'PO - BNEI - Break and enter in progress.docx',
#  'PO - BOMB - Bomb Threat.docx',
#  'PO - BOMB - Bomb threats.docx',
#  'PO - BREACH.docx',
#  'PO - Bylaw.docx',
#  'PO - CHECK - Check wellbeing.docx',
#  'PO - CHIM - Chimney Fire.docx',
#  'PO - COUNTERFEIT - Counterfeit Currency.docx',
#  'PO - DEMON - Demonstration.docx',
#  'PO - DISTB - Disturbance.docx',
#  'PO - DNA - DNA collection.docx',
#  'PO - DOMI - Domestic in progress.docx',
#  'PO - DOMRPT - Domestic report.docx',
#  'PO - DRUGS.docx',
#  'PO - ELEC12 - Electrical problem.docx',
#  'PO - EXP123 - Explosion.docx',
#  'PO - EXPLOS  - Explosion Explosives.docx',
#  'PO - EXTORT - Extortion.docx',
#  'PO - FIGHT - Fight.docx',
#  'PO - FIREAR - Firearm for Pickup Transport.docx',
#  'PO - FOUNDP - Found Person.docx',
#  'PO - FRAUD.docx',
#  'PO - GAS1234 - CompressedGasLeak.docx',
#  'PO - HARASS - Harassment.docx',
#  'PO - HAZARD - Hazard.docx',
#  'PO - HAZM123 - Hazardous Materials.docx',
#  'PO - HOMEIN - Home Invasion.docx',
#  'PO - HOSTAG - Hostage Situation.docx',
#  'PO - ILBRN - Illegal Burn.docx',
#  'PO - IMPAIR - Impaired driver.docx',
#  'PO - INDEC - Indecent Act.docx',
#  'PO - INDUST - Industrial Accident.docx',
#  'PO - INSEC - Insecure Premises Vehicle.docx',
#  'PO - INTELL - Intelligence Information.docx',
#  'PO - JUMPER.docx',
#  'PO - KPEACE - Keep the Peace.docx',
#  'PO - LIQUOR - Liquor Act Licensed Premises Check.docx',
#  'PO - MAND - Man Down.docx',
#  'PO - MARINE - Marine Incident.docx',
#  'PO - MED12A - Medical aid.docx',
#  'PO - MISCH - Mischief.docx',
#  'PO - MISCHI - Mischief in Progress.docx',
#  'PO - MISSIC - Missing Child - Reports.docx',
#  'PO - MISSIC - Missing Child.docx',
#  'PO - MISSIP - Missing person - Reports.docx',
#  'PO - MISSIP - Missing person.docx',
#  'PO - MUAID - Mutual aid.docx',
#  'PO - MVI - Motor Vehicle Incident.docx',
#  'PO - MVI12345 - Motor Vehicle Incident.docx',
#  'PO - MVIHR - Hit and Run.docx',
#  'PO - MVIINJ - Motor Vehicle Incident with injuries.docx',
#  'PO - MVIPOL - MVI with police vehicle.docx',
#  'PO - NOK - Next of kin notification.docx',
#  'PO - OCC - Other Criminal Code.docx',
#  'PO - ODOUU - Odour unknown source.docx',
#  'PO - OVERD - Overdose.docx',
#  'PO - PANHA - Panhandler.docx',
#  'PO - PARK - Parking complaint.docx',
#  'PO - POLE - Pole fire.docx',
#  'PO - PREV - Fire Prevention.docx',
#  'PO - PROP - Property - Reports.docx',
#  'PO - PROP - Property lost, found or seized.docx',
#  'PO - PROST - Prosititution situation.docx',
#  'PO - PROWL.docx',
#  'PO - Pursue.docx',
#  'PO - R - RECVEH - Recovered vehicle.docx',
#  'PO - R - SUSPP - Suspicious person.docx',
#  'PO - RECVEH - Recovered vehicle.docx',
#  'PO - RES123M - Rescue calls.docx',
#  'PO - ROBB - Robbery.docx',
#  'PO - ROBBI - Robbery in progress.docx',
#  'PO - RUBSH - Rubbish fire.docx',
#  'PO - SCOB - Single company, unit response.docx',
#  'PO - SCOLL - Structure collapse.docx',
#  'PO - SCREAM - Screams heard.docx',
#  'PO - SHIP123 - Ship fire.docx',
#  'PO - SHOPL - Shoplifter.docx',
#  'PO - SHOTS - Shots Fired Heard.docx',
#  'PO - SIP - SIPP DIPP.docx',
#  'PO - SMK123 - Report of smoke.docx',
#  'PO - SPAT - Special Attention Detail Event.docx',
#  'PO - ST123 - Structure fire.docx',
#  'PO - STALK - Stalking.docx',
#  'PO - STOVE - Stove fire.docx',
#  'PO - SUDDEN - Sudden Death.docx',
#  'PO - SUICID - Suicidal person.docx',
#  'PO - SUSPC - Suspicious Circumstances.docx',
#  'PO - SUSPP - Suspicious person.docx',
#  'PO - SUSPV - Suspicious vehicle.docx',
#  'PO - TEST - Test call.docx',
#  'PO - THEFT - Theft - Reports.docx',
#  'PO - THEFT.docx',
#  'PO - THEFTI - Theft in progress.docx',
#  'PO - THEFTV - Theft of Vehicle - Reports.docx',
#  'PO - THEFTV - Theft of vehicle.docx',
#  'PO - THREATS - Add jurisdiction names.docx',
#  'PO - THREATS.docx',
#  'PO - TRAFF - Traffic Complaint.docx',
#  'PO - TRAFFS - Traffic Stop.docx',
#  'PO - UNWANT - Unwanted person.docx',
#  'PO - VAULT.docx',
#  'PO - VEF123 - Vehicle fire.docx',
#  'PO - WARRAN - Warrant.docx',
#  'PO - WATER - Water problem.docx',
#  'PO - WEAPON.docx',
#  'PO - WILD123 - Wildfire reported.docx',
#  'PO - WIRE12 - Wires down.docx',
#  'PO - YOUTH.docx',
#  'RI -  MUAID - Mutual aid.docx',
#  'RI - 1033 - Officer in trouble.docx',
#  'RI - 911.docx',
#  'RI - AB911 cell.docx',
#  'RI - AB911 Landline.docx',
#  'RI - ABANDV - Abandoned vehicle.docx',
#  'RI - ABDUC - Abduction.docx',
#  'RI - ACEM - Aircraft Emergency Landing.docx',
#  'RI - ACF - Aircraft Fire.docx',
#  'RI - ACRA - Airplane Crash.docx',
#  'RI - AIREM - Airplane Crash.docx',
#  'RI - ALARM - Audible Alarm.docx',
#  'RI - ALARMA - Airport alarm.docx',
#  'RI - ALARMD - Domestic violence alarm.docx',
#  'RI - ALARMH - Holdup alarm.docx',
#  'RI - ALARMS - Silent or Panic Alarm.docx',
#  'RI - ALRM123 - Fire Alarm.docx',
#  'RI - ANIMAL.docx',
#  'RI - ANNOY - Annoying circumstance.docx',
#  'RI - ARREST.docx',
#  'RI - ARSON.docx',
#  'RI - ASIST - Calls for assistance.docx',
#  'RI - ASLT - Assault.docx',
#  'RI - ASLTI - Assault in Progress.docx',
#  'RI - ASLTSX - Sexual assault.docx',
#  'RI - ASSGP - Assist General Public.docx',
#  'RI - ASSMHA - Assist Mental Health Act.docx',
#  'RI - ASSOA - Assist Other Agency.docx',
#  'RI - ASSPFA - Assist Police Fire Ambulance.docx',
#  'RI - BAIT-Bait Car Activation.docx',
#  'RI - BBQF.docx',
#  'RI - BNE - Break and Enter.docx',
#  'RI - BNEI - Break and enter in progress.docx',
#  'RI - BOMB - Bomb Threat.docx',
#  'RI - BOMB - Bomb threats.docx',
#  'RI - BREACH.docx',
#  'RI - Bylaw.docx',
#  'RI - CHECK - Check wellbeing.docx',
#  'RI - CHIM - Chimney Fire.docx',
#  'RI - COUNTERFEIT - Counterfeit Currency.docx',
#  'RI - DEMON - Demonstration.docx',
#  'RI - DISTB - Disturbance.docx',
#  'RI - DNA - DNA collection.docx',
#  'RI - DOMI - Domestic in progress.docx',
#  'RI - DOMRPT - Domestic report.docx',
#  'RI - DRUGS - Drugs.docx',
#  'RI - DRUGS.docx',
#  'RI - ELEC12 - Electrical problem.docx',
#  'RI - EXP123 - Explosion.docx',
#  'RI - EXPLOS  - Explosion Explosives.docx',
#  'RI - EXTORT - Extortion.docx',
#  'RI - FIGHT - Fight.docx',
#  'RI - FIREAR - Firearm for Pickup Transport.docx',
#  'RI - FOUNDP - Found Person.docx',
#  ...]

# %%
juris, types, fullname = list(), list(), list()
excl_juris, excl_types, excl_docs, excl_fullname = list(), list(), list(), list()
unmatched_sops = list()

sopreg = r'^([A-Z]+)[ -]*([\w ]+)-([\w ,]*).docx'

for sop in sop_list:
    isExcluded = re.search(r'|'.join(exclude_docs), sop, re.IGNORECASE)
    if isExcluded:
        unmatched_sops.append(sop)
        continue
        
    match = re.findall(r'^([A-Z]+)[ -]+([\w ]*)-([\w ,]*).docx', sop, re.IGNORECASE)
    if not match:
        unmatched_sops.append(sop)
        continue
        
    juri, acrn, doc = match[0]
    juri = re.sub(' ', '', juri.upper())
    doc = doc.upper().strip()
    acrn = acrn.upper().strip()
    if juri not in juri_list:
        excl_juris.append(juri)
        excl_types.append(acrn)
        excl_docs.append(doc)
        excl_fullname.append(sop)
        continue
        
    type_adjust = doc if len(acrn) == 0 else acrn
    juris.append(juri)
    types.append(type_adjust)
    fullname.append(sop)
    
sop_docs = pd.DataFrame({'juri': juris, 'type': types, 'filename': fullname})

sop_unmatched = pd.DataFrame({'filename': unmatched_sops})

sop_excludedjuri = pd.DataFrame({'juri': excl_juris, 'type': excl_docs, 'filename': excl_fullname})

# %%
sop_docs
# Out:
#      juri            type                              filename
# 0      AB            1033   AB - 1033 - Officer in trouble.docx
# 1      AB             911                         AB - 911.docx
# 2      AB      AB911 CELL                  AB - AB911 cell.docx
# 3      AB  AB911 LANDLINE              AB - AB911 Landline.docx
# 4      AB          ABANDV  AB - ABANDV - Abandoned vehicle.docx
# ...   ...             ...                                   ...
# 1621   WV          TRAFFS       WV - TRAFFS - Traffic Stop.docx
# 1622   WV          UNWANT    WV - UNWANT - Unwanted person.docx
# 1623   WV          WARRAN            WV - WARRAN - Warrant.docx
# 1624   WV          WEAPON                      WV - WEAPON.docx
# 1625   WV           YOUTH                       WV - YOUTH.docx
#
# [1626 rows x 3 columns]

# %%
type_to_juri = sop_docs \
    .groupby('type') \
    .agg({'juri': lambda x: list(x), 'filename': lambda x: list(x)}) \
    .reset_index()
type_to_juri.loc[:, 'juri_count'] = type_to_juri.loc[:, 'juri'].apply(len)
type_to_juri = type_to_juri.sort_values(by = 'juri_count', ascending = False, ignore_index = True)
type_to_juri
# Out:
#        type                                               juri  \
# 0      1033  [AB, BI, BU, DE, DFPF, NW, PO, RI, RM, SC, SQ,...
# 1      DOMI  [AB, BI, BU, DE, DFPF, NW, PO, RI, RM, SC, SQ,...
# 2    FOUNDP  [AB, BI, BU, DE, DFPF, NW, PO, RI, RM, SC, SQ,...
# 3    HAZARD  [AB, BI, BU, DE, DFPF, NW, PO, RI, RM, SC, SQ,...
# 4    IMPAIR  [AB, BI, BU, DE, DFPF, NW, PO, RI, RM, SC, SQ,...
# ..      ...                                                ...
# 123  ALARMA                                           [AB, RI]
# 124   BORDR                                           [AB, DE]
# 125   FBOAT                                               [VA]
# 126  ELEC12                                               [NW]
# 127    ACEM                                               [RI]
#
#                                               filename  juri_count
# 0    [AB - 1033 - Officer in trouble.docx, BI - 103...          16
# 1    [AB - DOMI - Domestic in progress.docx, BI - D...          16
# 2    [AB - FOUNDP - Found Person.docx, BI - FOUNDP ...          16
# 3    [AB - HAZARD - Hazard.docx, BI - HAZARD - Haza...          16
# 4    [AB - IMPAIR - Impaired driver.docx, BI - IMPA...          16
# ..                                                 ...         ...
# 123  [AB - ALARMA - Airport alarm.docx, RI - ALARMA...           2
# 124  [AB - BORDR - Border Runner.docx, DE - BORDR -...           2
# 125                  [VA - FBOAT - Fireboat call.docx]           1
# 126                                 [NW - ELEC12.docx]           1
# 127      [RI - ACEM - Aircraft Emergency Landing.docx]           1
#
# [128 rows x 4 columns]

# %%
type_to_juri['juri_count'].unique()
# Out:
# array([16, 15, 14,  5,  2,  1], dtype=int64)

# %%
type_to_juri_ok = type_to_juri[type_to_juri['juri_count'] >= 13]
type_to_juri_5 = type_to_juri[type_to_juri['juri_count'] == 5]
type_to_juri_2 = type_to_juri[type_to_juri['juri_count'] == 2]
type_to_juri_1 = type_to_juri[type_to_juri['juri_count'] == 1]

# %%
type_to_juri_ok['type'].unique()
# Out:
# array(['1033', 'DOMI', 'FOUNDP', 'HAZARD', 'IMPAIR', '911', 'INTELL',
#        'JUMPER', 'MAND', 'MISCH', 'MISCHI', 'MVI', 'MVIHR', 'MVIINJ',
#        'OCC', 'PANHA', 'PROP', 'PURSUE', 'RECVEH', 'SCREAM', 'SHOTS',
#        'SIP', 'SUDDEN', 'SUICID', 'SUSPC', 'SUSPP', 'THEFTV', 'THREATS',
#        'TRAFF', 'TRAFFS', 'WEAPON', 'DRUGS', 'INSEC', 'ANIMAL', 'ASSOA',
#        'ABANDV', 'ARREST', 'ARSON', 'MVIPOL', 'PARK', 'ANNOY', 'OVERD',
#        'NOK', 'BREACH', 'PROWL', 'ASLT', 'MISSIP', 'MISSIC', 'ASLTI',
#        'ASLTSX', 'PROST', 'ALARMS', 'ASSGP', 'THEFT', 'AB911 CELL',
#        'WARRAN', 'UNWANT', 'AB911 LANDLINE', 'ABDUC', 'THEFTI', 'SUSPV',
#        'ROBB', 'AIREM', 'ALARM', 'STALK', 'SHOPL', 'ALARMH', 'ROBBI',
#        'MARINE', 'YOUTH', 'LIQUOR', 'COUNTERFEIT', 'EXPLOS', 'EXTORT',
#        'BNEI', 'DOMRPT', 'FIGHT', 'FIREAR', 'BOMB', 'BNE', 'FRAUD',
#        'DISTB', 'HARASS', 'DEMON', 'ASSPFA', 'HOMEIN', 'HOSTAG', 'BAIT',
#        'CHECK', 'BYLAW', 'INDEC', 'KPEACE', 'INDUST', 'ASSMHA', 'SPAT',
#        'ALARMD', 'DNA'], dtype=object)

# %%
os.chdir(notebook_dir)
type_to_juri_ok.to_csv('../data/interim/sop_types_valid.csv', index = False)
type_to_juri_excluded = type_to_juri[type_to_juri['juri_count'] < 13]
type_to_juri_excluded.to_csv('../data/interim/sop_types_excluded.csv', index = False)
sop_excludedjuri.to_csv('../data/interim/sop_excluded_due_to_juris.csv', index = False)
sop_unmatched.to_csv('../data/interim/sop_excluded_due_to_type.csv', index = False)

# %%
# Added by Jake

def para_to_text(p):
    """
    A function to find every texts in the paragraph

    params
    ----
    p : docx.Document.Paragraph object

    returns
    ----
    str 

    """
    rs = p._element.xpath(".//w:t")
    return u"".join([r.text for r in rs])

# %%
def parse_docx_role(filepath):
    with open(filepath, 'rb') as f:
        source_stream = BytesIO(f.read())
    f.close()
    doc = Document(source_stream)
    paras = doc.paragraphs
    res = dict()
    role = None
    texts, level = list(), list()
    for p in paras:
        style = p.style.name
        text = para_to_text(p).strip()
        
        if len(text) == 0:
            continue
        if style == 'Heading 1':
            role = re.findall(r'([\w ]+)', text.lower())[0]
            res[role] = list()
        elif role is not None:
            res[role].append(text)
    return res

# %% [markdown]
# > Because the SOP documents have inconsistent file structure, I will parse on the event type level
#
# > For example, the "1033" event type doesn't have situations
# ![](img/sop_doc_inconsistent_level.PNG)

# %%
def parse_one_event(curr_row):
    cwd = os.getcwd()
    os.chdir(sop_dir)
    event_type = curr_row['type']
    jsons = dict()
    for juri, file in zip(curr_row['juri'], curr_row['filename']):
        jsons[juri] = parse_docx_role(file)
    os.chdir(cwd)
    return jsons

# %%
num_rows = type_to_juri_ok.shape
num_rows
# Out:
# (97, 4)

# %%
os.chdir(notebook_dir)

# %%
for i in range(num_rows[0]):
    row = type_to_juri_ok.iloc[i, :]
    event = parse_one_event(row)
    doctype = row['type']
    outfile_name = f'../data/sop_jsons/{doctype}.txt'
    with open(outfile_name, 'w') as outfile:
        json.dump(event, outfile)
    outfile.close()

# %%
# with open('../data/sop_jsons/PROP.txt') as f:
#     jj = json.load(f)
# print(json.dumps(jj, indent = 4))

# %%
def parse_docx_role_df(filepath):
    with open(filepath, 'rb') as f:
        source_stream = BytesIO(f.read())
    f.close()
    doc = Document(source_stream)
    paras = doc.paragraphs
    res = dict()
    role = None
    texts, level = list(), list()
    for p in paras:
        style = p.style.name
        text = para_to_text(p)
        texts.append(text)
        level.append(style)
    return pd.DataFrame({'text': texts, 'level': level})

# %%
os.getcwd()
os.chdir(sop_dir)

# %%
os.chdir(sop_dir)
parse_docx_role_df('BU - TRAFFS - Traffic Stop.docx')[:30]
# Out:
#                                                  text      level
# 0   This SOP covers the TRAFFS – Traffic suspensio...     Normal
# 1                                          call taker  Heading 1
# 2                                          Do not use     Style1
# 3                                         Dispatcher   Heading 1
# 4                                       Create a call     Style1
# 5                                              Record     Style1
# 6                                          Start time     Style1
# 7                                     Vehicle details     Style1
# 8                Impoundment information and duration     Style1
# 9                                 Type of suspension      Style1
# 10                            215s (12 hour MVA 90.3)     Style1
# 11                            215s (24 hour MVA 215s)     Style1
# 12                                                IRP     Style1
# 13                                 Driver information     Style1
# 14  Forward the call to ER1 and add the following ...     Style1
# 15           Whether it is a 12 or 24 hour suspension     Style1
# 16                   Start time of suspension (XX:XX)     Style1
# 17                                        Driver name     Style1
# 18                                         Driver DOB     Style1
# 19                                         Driver BCL     Style1
# 20                                      License plate     Style1
# 21                             Colour and make of car     Style1
# 22                            Where vehicle was towed     Style1
# 23                                Vehicle impoundment  Heading 2
# 24                                      Create a call     Style1
# 25                                  Assign the member     Style1

# %%
def parse_docx_situation_df(doc_type, juri, filepath):
    with open(sop_dir + filepath, 'rb') as f:
        source_stream = BytesIO(f.read())
    f.close()
    doc = Document(source_stream)
    paras = doc.paragraphs
    res = pd.DataFrame()
    role, situation = None, ''
    roles, situations, texts = list(), list(), list()
    types, juris, files = list(), list(), list()
    for p in paras:
        style = p.style.name
        text = para_to_text(p)
        if re.search(r'type is not used', text.lower()):
            return res
        if len(text) == 0:
            continue
        if style == 'Normal':
            role, situation = None, ''
        elif style == 'Heading 1':
            role = re.findall(r'([\w ]+)', text.lower())[0].strip()
#             print(role)
            situation = ''
        elif style == 'Heading 2':
            situation = text.strip()
        elif role is not None:
            text = text.strip()
            roles.append(role)
            situations.append(situation)
            texts.append(text)
            
    res = pd.DataFrame({'role': roles, 'situation': situations, 'sop': texts}) \
        .groupby(['role', 'situation']) \
        .agg({'sop': lambda x: list(x)}) \
        .reset_index()
    res['juri'] = juri
    res['type'] = doc_type
    res['filename'] = filepath
    res = res[['type', 'juri', 'role', 'situation', 'sop', 'filename']]
    return res

# %%
def parse_docx_situation_df2(doc_type, juri, filepath):
    with open(sop_dir + filepath, 'rb') as f:
        source_stream = BytesIO(f.read())
    f.close()
    doc = Document(source_stream)
    paras = doc.paragraphs
    res = pd.DataFrame()
    role, situation = None, ''
    roles, situations, texts = list(), list(), list()
    types, juris, files = list(), list(), list()
    for p in paras:
        style = p.style.name
        text = para_to_text(p)
#         if re.search(r'type is not used', text.lower()):
#             return res
        if len(text) == 0:
            continue
        if style == 'Normal':
#             role, situation = None, ''
            continue
        elif style == 'Heading 1':
            role = re.findall(r'([\w ]+)', text.lower())[0].strip()
#             print(role)
            situation = ''
        elif style == 'Heading 2':
            situation = text.strip()
        elif role is not None:
            text = text.strip()
            roles.append(role)
            situations.append(situation)
            texts.append(text)
            
    res = pd.DataFrame({'role': roles, 'situation': situations, 'sop': texts}) \
        .groupby(['role', 'situation']) \
        .agg({'sop': lambda x: list(x)}) \
        .reset_index()
    res['juri'] = juri
    res['type'] = doc_type
    res['filename'] = filepath
    res = res[['type', 'juri', 'role', 'situation', 'sop', 'filename']]
    return res

# %%
parse_docx_situation_df2('TRAFFS', 'BU', 'BU - TRAFFS - Traffic Stop.docx')
# Out:
#      type juri        role            situation  \
# 0  TRAFFS   BU  call taker
# 1  TRAFFS   BU  dispatcher
# 2  TRAFFS   BU  dispatcher  Vehicle impoundment
#
#                                                  sop  \
# 0                                       [Do not use]
# 1  [Create a call, Record, Start time, Vehicle de...
# 2                 [Create a call, Assign the member]
#
#                           filename
# 0  BU - TRAFFS - Traffic Stop.docx
# 1  BU - TRAFFS - Traffic Stop.docx
# 2  BU - TRAFFS - Traffic Stop.docx

# %%
def get_all_situations(df):
    df_all_situation = pd.DataFrame()
    for i in range(len(df)):
        row = df.iloc[i, :]
        doc_type = row['type']
        for juri, filename in zip(row['juri'], row['filename']):
            situ_df = parse_docx_situation_df(doc_type, juri, filename)
            df_all_situation = df_all_situation.append(situ_df)
    return df_all_situation.reset_index(drop = True)

# %%
def get_all_situations2(df):
    df_all_situation = pd.DataFrame()
    for i in range(len(df)):
        row = df.iloc[i, :]
        doc_type = row['type']
        for juri, filename in zip(row['juri'], row['filename']):
            situ_df = parse_docx_situation_df2(doc_type, juri, filename)
            df_all_situation = df_all_situation.append(situ_df)
    return df_all_situation.reset_index(drop = True)

# %%
type_to_juri_ok
# Out:
#       type                                               juri  \
# 0     1033  [AB, BI, BU, DE, DFPF, NW, PO, RI, RM, SC, SQ,...
# 1     DOMI  [AB, BI, BU, DE, DFPF, NW, PO, RI, RM, SC, SQ,...
# 2   FOUNDP  [AB, BI, BU, DE, DFPF, NW, PO, RI, RM, SC, SQ,...
# 3   HAZARD  [AB, BI, BU, DE, DFPF, NW, PO, RI, RM, SC, SQ,...
# 4   IMPAIR  [AB, BI, BU, DE, DFPF, NW, PO, RI, RM, SC, SQ,...
# ..     ...                                                ...
# 92  INDUST  [AB, BI, BU, DE, NW, PO, RI, RM, SC, SQ, SX, U...
# 93  ASSMHA  [AB, BI, BU, DE, NW, PO, RI, RM, SC, SQ, SX, U...
# 94    SPAT  [BI, BU, DE, NW, PO, RI, RM, SC, SQ, SX, UN, V...
# 95  ALARMD  [AB, BI, BU, DE, NW, PO, RI, RM, SC, SQ, SX, V...
# 96     DNA  [BI, BU, DE, NW, PO, RI, RM, SC, SQ, SX, UN, V...
#
#                                              filename  juri_count
# 0   [AB - 1033 - Officer in trouble.docx, BI - 103...          16
# 1   [AB - DOMI - Domestic in progress.docx, BI - D...          16
# 2   [AB - FOUNDP - Found Person.docx, BI - FOUNDP ...          16
# 3   [AB - HAZARD - Hazard.docx, BI - HAZARD - Haza...          16
# 4   [AB - IMPAIR - Impaired driver.docx, BI - IMPA...          16
# ..                                                ...         ...
# 92  [AB - INDUST - Industrial Accident.docx, BI - ...          15
# 93  [AB - ASSMHA - Assist Mental Health Act.docx, ...          15
# 94  [BI - SPAT - Special Attention Detail Event.do...          14
# 95  [AB - ALARMD - Domestic violence alarm.docx, B...          14
# 96  [BI - DNA - DNA collection.docx, BU - DNA - DN...          14
#
# [97 rows x 4 columns]

# %%
# type_to_juri_ok = pd.read_csv(
#     notebook_dir + '/../data/interim/sop_types_valid.csv',
#     keep_default_na = False, 
#     converters = {'juri': eval, 'filename': eval}
# )

# %%
df_all_situation = get_all_situations2(type_to_juri_ok)

# %%
df_all_situation[ (df_all_situation['type'] == 'TRAFFS') 
                & (df_all_situation['role'] == 'call taker')]
# Out:
#         type  juri        role situation                       sop  \
# 2782  TRAFFS    AB  call taker            [event type is not used]
# 2785  TRAFFS    BI  call taker             [Call type is not used]
# 2788  TRAFFS    BU  call taker                        [Do not use]
# 2791  TRAFFS    DE  call taker            [event type is not used]
# 2794  TRAFFS  DFPF  call taker             [Call type is not used]
# 2797  TRAFFS    NW  call taker             [Call type is not used]
# 2800  TRAFFS    PO  call taker             [Call type is not used]
# 2803  TRAFFS    RI  call taker             [Call type is not used]
# 2806  TRAFFS    RM  call taker             [Call type is not used]
# 2809  TRAFFS    SC  call taker             [Call type is not used]
# 2812  TRAFFS    SQ  call taker             [Call type is not used]
# 2815  TRAFFS    SX  call taker             [Call type is not used]
# 2818  TRAFFS    UN  call taker             [Call type is not used]
# 2821  TRAFFS    VA  call taker             [Call type is not used]
# 2823  TRAFFS    WP  call taker             [Call type is not used]
# 2826  TRAFFS    WV  call taker             [Call type is not used]
#
#                                filename
# 2782    AB - TRAFFS - Traffic Stop.docx
# 2785    BI - TRAFFS - Traffic Stop.docx
# 2788    BU - TRAFFS - Traffic Stop.docx
# 2791    DE - TRAFFS - Traffic Stop.docx
# 2794  DFPF - TRAFFS - Traffic Stop.docx
# 2797    NW - TRAFFS - Traffic Stop.docx
# 2800    PO - TRAFFS - Traffic Stop.docx
# 2803    RI - TRAFFS - Traffic Stop.docx
# 2806    RM - TRAFFS - Traffic Stop.docx
# 2809    SC - TRAFFS - Traffic Stop.docx
# 2812    SQ - TRAFFS - Traffic Stop.docx
# 2815    SX - TRAFFS - Traffic Stop.docx
# 2818    UN - TRAFFS - Traffic Stop.docx
# 2821    VA - TRAFFS - Traffic Stop.docx
# 2823    WP - TRAFFS - Traffic Stop.docx
# 2826    WV - TRAFFS - Traffic Stop.docx

# %%
os.chdir(notebook_dir)
df_all_situation.to_csv('../data/interim/all_situation.csv', index = False)

# %%
df_call = df_all_situation[ 
    (df_all_situation['role'] == 'call taker') 
    & (df_all_situation['situation'].str.len() > 0)
].reset_index(drop = True)
df_call
# Out:
#         type juri        role                     situation  \
# 0       1033   DE  call taker             CBSA alarm policy
# 1       DOMI   AB  call taker        All other DOMI reports
# 2       DOMI   AB  call taker              GPS Panic Alarms
# 3     FOUNDP   AB  call taker              Address Obtained
# 4     FOUNDP   AB  call taker  Name or medic alert is known
# ...      ...  ...         ...                           ...
# 3710     DNA   SX  call taker                  DNA Warrant:
# 3711     DNA   UN  call taker                  DNA Warrant:
# 3712     DNA   VA  call taker                  DNA Warrant:
# 3713     DNA   WP  call taker                  DNA Warrant:
# 3714     DNA   WV  call taker                  DNA Warrant:
#
#                                                     sop  \
# 0     [Listen to alarm, Acknowledge the alarm by pre...
# 1     [Create a call in every instance. Do not cance...
# 2     [Create a call, Remain on the line recording a...
# 3     [Run address on QBA:, If the person is negativ...
# 4     [Run name on CPIC, If the person is negative o...
# ...                                                 ...
# 3710                        [See WARRAN (Warrants) SOP]
# 3711                        [See WARRAN (Warrants) SOP]
# 3712                        [See WARRAN (Warrants) SOP]
# 3713                        [See WARRAN (Warrants) SOP]
# 3714                        [See WARRAN (Warrants) SOP]
#
#                                    filename
# 0       DE - 1033 - Officer in trouble.docx
# 1     AB - DOMI - Domestic in progress.docx
# 2     AB - DOMI - Domestic in progress.docx
# 3           AB - FOUNDP - Found Person.docx
# 4           AB - FOUNDP - Found Person.docx
# ...                                     ...
# 3710         SX - DNA - DNA collection.docx
# 3711         UN - DNA - DNA collection.docx
# 3712         VA - DNA - DNA collection.docx
# 3713         WP - DNA - DNA collection.docx
# 3714         WV - DNA - DNA collection.docx
#
# [3715 rows x 6 columns]

# %%
df_call.to_csv('../data/interim/calltaker_situation.csv', index = False)

# %%
df_dispatcher = df_all_situation[ 
    (df_all_situation['role'] == 'dispatcher') 
    & (df_all_situation['situation'].str.len() > 0)
].reset_index(drop = True)
df_call.to_csv('../data/interim/dispatcher_situation.csv', index = False)
df_dispatcher
# Out:
#       type juri        role  \
# 0     1033   AB  dispatcher
# 1     1033   BI  dispatcher
# 2     1033   BU  dispatcher
# 3     1033   DE  dispatcher
# 4     1033   DE  dispatcher
# ...    ...  ...         ...
# 3073  SPAT   WP  dispatcher
# 3074  SPAT   WV  dispatcher
# 3075  SPAT   WV  dispatcher
# 3076   DNA   NW  dispatcher
# 3077   DNA   RM  dispatcher
#
#                                               situation  \
# 0             1033 activations by member over the radio
# 1             1033 activations by member over the radio
# 2             1033 activations by member over the radio
# 3             1033 activations by member over the radio
# 4                                            CBSA alarm
# ...                                                 ...
# 3073  Government Building, Agency, Consulate or Othe...
# 3074                                Commercial Premises
# 3075  Government Building, Agency, Consulate or Othe...
# 3076  Person attends front counter or member request...
# 3077                            CPIC narrative requests
#
#                                                     sop  \
# 0     [Refer to Instructions – Emergency Key Activat...
# 1     [Refer to Instructions – Emergency Key Activat...
# 2     [Refer to Instructions – Emergency Key Activat...
# 3     [Refer to Instructions – Emergency Key Activat...
# 4     [If the CBSA alarm key rings on your phone set...
# ...                                                 ...
# 3073  [Assign a member, It is the responsibility of ...
# 3074  [Assign a member, It is the responsibility of ...
# 3075  [Assign a member, It is the responsibility of ...
# 3076  [Canvas for DNA certified member, Contact Watc...
# 3077  [All requests for DNA sample collection are to...
#
#                                              filename
# 0                 AB - 1033 - Officer in trouble.docx
# 1                 BI - 1033 - Officer in trouble.docx
# 2                 BU - 1033 - Officer in trouble.docx
# 3                 DE - 1033 - Officer in trouble.docx
# 4                 DE - 1033 - Officer in trouble.docx
# ...                                               ...
# 3073  WP - SPAT - Special Attention Detail Event.docx
# 3074  WV - SPAT - Special Attention Detail Event.docx
# 3075  WV - SPAT - Special Attention Detail Event.docx
# 3076                  NW - DNA - DNA collection .docx
# 3077                   RM - DNA - DNA collection.docx
#
# [3078 rows x 6 columns]
