# %%
import networkx as nx
from docx import Document
from io import StringIO, BytesIO
import os
import spacy
from spacy import displacy
from spacy.pipeline import EntityRuler

# %%
path = "/Users/Public/Desktop/SOPs/"
SOPs = os.listdir(path)

# %%
def para_to_text(p):
    """
    A function to find every texts in the paragraph

    params
    ----
    p : docx.Document.Paragraph object

    returns
    ----
    str 

    """
    rs = p._element.xpath(".//w:t")
    return "".join([r.text for r in rs])


def sop_to_text(file_path):
    """
    Converts SOP.docx into plain text

    params
    ----
    file_path : str (path to the SOP document) 

    returns
    ----
    str
    """
    text = []
    with open(file_path, 'rb') as f:
        source_stream = BytesIO(f.read())
    f.close()

    doc = Document(source_stream)
    paras = doc.paragraphs
    for p in paras:
        text.append(para_to_text(p))
            
    text = " ".join(text).strip()
    return text

# %% [markdown]
# ## Knowledge Based Graph

# %% [markdown]
# ### Entity Extraction Status

# %%
nlp = spacy.load("./entity_train/ecomm_ner/")

# %%
colors = {"EVENT": "#FFCB41",
         "SITUATION": "#C7FF7E",
         "ACTION": "#FF625F",
         "QUESTION": "#D89CFF",
         "ROLE": "#7DC9FF" ,
         "CONDITION": "#FBB9F6" ,
         }
options = {"colors":colors}

# %%
file_path = path + "BI - SHOPL - Shoplifter.docx"

text = sop_to_text(file_path)

doc = nlp(text)
displacy.render(nlp(str(doc)), jupyter=True, style='ent', options=options)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">This is the SOP for the
# <mark class="entity" style="background: #FFCB41; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SHOPL – Shoplifter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  event type. Calls will usually be received from commercial premises where a suspect has been apprehended. Staff will usually be Loss Prevention Officers who will identify themselves by name and Personal Identification Number. Under most circumstances confidentiality laws prohibit releasing CPIC or PRIME information to the LPO.
# <mark class="entity" style="background: #7DC9FF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     call taker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ROLE</span>
# </mark>
#
# <mark class="entity" style="background: #C7FF7E; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adult or juvenile - Trouble holding
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SITUATION</span>
# </mark>
#
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Create
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  a call
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Upgrade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  to priority 1  Questions
# <mark class="entity" style="background: #D89CFF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Where is the suspect being held?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUESTION</span>
# </mark>
#
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Run
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  suspect on CPIC and PRIME
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Attach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  positive responses and make a note in the call
# <mark class="entity" style="background: #C7FF7E; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Juvenile – No trouble holding
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SITUATION</span>
# </mark>
#
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Create
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  a call Questions
# <mark class="entity" style="background: #D89CFF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Where is the suspect being held?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUESTION</span>
# </mark>
#
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Run
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  suspect on CPIC and PRIME
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Attach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  positive responses and make a note in the call
# <mark class="entity" style="background: #C7FF7E; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     No Photo ID – No trouble holding
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SITUATION</span>
# </mark>
#
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Create
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  a call Questions
# <mark class="entity" style="background: #D89CFF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Where is the suspect being held?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUESTION</span>
# </mark>
#
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Run
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  suspect on CPIC and PRIME
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Attach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  positive responses and make a note in the call
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Make
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  note of no photo ID in the call
# <mark class="entity" style="background: #C7FF7E; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adult – No trouble holding and LPO pressing charges
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SITUATION</span>
# </mark>
#
# <mark class="entity" style="background: #FF625F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Create
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTION</span>
# </mark>
#  a call Questions
# <mark class="entity" style="background: #D89CFF; padding: 0.45em 0.6em; ma

# %% [markdown]
# ### Entity Linking/Pairing

# %%
import pandas as pd 

ent_df = pd.DataFrame(columns = ["ENTITY","TYPE"])
ent_df["ENTITY"] = [ent.text for ent in doc.ents]
ent_df["TYPE"] = [ent.label_ for ent in doc.ents]

# %%
# Distinguish Main EVENT Type from other referred EVENT Types
event_inds = list(ent_df[ent_df["TYPE"] == "EVENT"].index)
ent_df.iloc[event_inds[0]]["TYPE"] = "MAIN_EVENT"
ent_df.iloc[event_inds[1:]]["TYPE"] = "ADR_EVENT"

# %%
def sop_entity_hierarchy(entity_type):
    """
    Determine entity's hierarchy by its type
    
    Params
    ----
    Entity - spacy.Document.Entity's type
    
    Returns
    ----
    int
    """
    rank_dict = {"MAIN_EVENT": 1,
                 "ROLE": 2,
                 "SITUATION": 3,
                 "QUESTION": 4,
                 "CONDITION": 4,
                 "ACTION": 5,
                 "ADR_EVENT": 6} # referred event
    
    return rank_dict[entity_type]

# %%
ent_df["RANKING"] = [sop_entity_hierarchy(x) for x in ent_df["TYPE"]]

# %%
ent_df
# Out:
#                                                ENTITY        TYPE  RANKING
# 0                                  SHOPL – Shoplifter  MAIN_EVENT        1
# 1                                          call taker        ROLE        2
# 2                 Adult or juvenile - Trouble holding   SITUATION        3
# 3                                              Create      ACTION        5
# 4                                             Upgrade      ACTION        5
# 5                    Where is the suspect being held?    QUESTION        4
# 6                                                 Run      ACTION        5
# 7                                              Attach      ACTION        5
# 8                       Juvenile – No trouble holding   SITUATION        3
# 9                                              Create      ACTION        5
# 10                   Where is the suspect being held?    QUESTION        4
# 11                                                Run      ACTION        5
# 12                                             Attach      ACTION        5
# 13                   No Photo ID – No trouble holding   SITUATION        3
# 14                                             Create      ACTION        5
# 15                   Where is the suspect being held?    QUESTION        4
# 16                                                Run      ACTION        5
# 17                                             Attach      ACTION        5
# 18                                               Make      ACTION        5
# 19  Adult – No trouble holding and LPO pressing ch...   SITUATION        3
# 20                                             Create      ACTION        5
# 21                   Where is the suspect being held?    QUESTION        4
# 22                                                Run      ACTION        5
# 23                                             Attach      ACTION        5
# 24  Adult – No trouble holding and LPO not pressin...   SITUATION        3
# 25                                                Run      ACTION        5
# 26  If suspect has an enforceable CPIC entry or sp...   CONDITION        4
# 27                                             Create      ACTION        5
# 28                   Where is the suspect being held?    QUESTION        4
# 29                                             Advise      ACTION        5
# 30  If suspect does not have an enforceable CPIC e...   CONDITION        4
# 31                                             Advise      ACTION        5
# 32                                         Dispatcher        ROLE        2
# 33                Adult or juvenile - Trouble holding   SITUATION        3
# 34                                             Assign      ACTION        5
# 35                      Juvenile – No trouble holding   SITUATION        3
# 36                                             Assign      ACTION        5
# 37                   No Photo ID – No trouble holding   SITUATION        3
# 38                                             Assign      ACTION        5
# 39  Adult – No trouble holding and LPO pressing ch...   SITUATION        3
# 40                                             Assign      ACTION        5
# 41  Adult – No trouble holding and LPO not pressin...   SITUATION        3
# 42                                             Assign      ACTION        5

# %%
index_by_type = ent_df.groupby(["TYPE"]).groups
index_by_type
# Out:
# {'ACTION': Int64Index([ 3,  4,  6,  7,  9, 11, 12, 14, 16, 17, 18, 20, 22, 23, 25, 27, 29,
#              31, 34, 36, 38, 40, 42],
#             dtype='int64'),
#  'CONDITION': Int64Index([26, 30], dtype='int64'),
#  'MAIN_EVENT': Int64Index([0], dtype='int64'),
#  'QUESTION': Int64Index([5, 10, 15, 21, 28], dtype='int64'),
#  'ROLE': Int64Index([1, 32], dtype='int64'),
#  'SITUATION': Int64Index([2, 8, 13, 19, 24, 33, 35, 37, 39, 41], dtype='int64')}

# %%
ent_pairs = []

# %%
# MAIN_EVENT - ROLE
for i in index_by_type["ROLE"]:
    ent_pairs.append((ent_df["ENTITY"][0] , ent_df["ENTITY"][i]))

# %%
# ROLE - SITUATION
checkpoint = len(ent_df)

role_ind = index_by_type["ROLE"]
sit_ind = index_by_type["SITUATION"]

for i in range(0,len(role_ind)-1):
    start = role_ind[i]
    end = role_ind[i+1]
    for j in range(0,len(sit_ind)):
        if start < sit_ind[j] < end:
            ent_pairs.append([ent_df["ENTITY"][role_ind[i]], ent_df["ENTITY"][sit_ind[j]]])
        else:
            break
            
for k in sit_ind[j:]:
    ent_pairs.append((ent_df["ENTITY"][end], ent_df["ENTITY"][k]))

# %%
# SITUATION - ACTION/CONDITION/QUESTION

# %%
ent_pairs
# Out:
# [('SHOPL – Shoplifter', 'call taker'),
#  ('SHOPL – Shoplifter', 'Dispatcher'),
#  ['call taker', 'Adult or juvenile - Trouble holding'],
#  ['call taker', 'Juvenile – No trouble holding'],
#  ['call taker', 'No Photo ID – No trouble holding'],
#  ['call taker', 'Adult – No trouble holding and LPO pressing charges'],
#  ['call taker', 'Adult – No trouble holding and LPO not pressing charges'],
#  ('Dispatcher', 'Adult or juvenile - Trouble holding'),
#  ('Dispatcher', 'Juvenile – No trouble holding'),
#  ('Dispatcher', 'No Photo ID – No trouble holding'),
#  ('Dispatcher', 'Adult – No trouble holding and LPO pressing charges'),
#  ('Dispatcher', 'Adult – No trouble holding and LPO not pressing charges')]

# %% [markdown]
# ## Drawing Knowledge Graph with NetworkX

# %%
G = nx.DiGraph()

# %%
G.add_edges_from(ent_pairs)

# %%
color_map = []
color_map.extend(["red"]*len(index_by_type["MAIN_EVENT"]))
color_map.extend(["blue"]*len(index_by_type["ROLE"]))
color_map.extend(["yellow"]*len(set(ent_df.iloc[index_by_type["SITUATION"]]["ENTITY"])))

# %%
from networkx.drawing.nx_pydot import pydot_layout

plt.figure(figsize=(30,10))
nx.nx_pydot.write_dot(G, "example.dot")

plt.title(file_path.split("/")[-1])
pos = pydot_layout(G, prog='dot')
nx.draw_networkx_labels(G, pos, font_size=20)
nx.draw(G, pos, with_labels=False, node_color = color_map)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-39305d6a8b52> in <module>
#       1 from networkx.drawing.nx_pydot import pydot_layout
#       2
# ----> 3 plt.figure(figsize=(30,10))
#       4 nx.nx_pydot.write_dot(G, "example.dot")
#       5
#
# NameError: name 'plt' is not defined

# %%
# !dot -Tpng example.dot -o example.png
# Out:
# (dot.exe:924): Pango-WARNING **: Invalid UTF-8 string passed to pango_layout_set_text()
#
# (dot.exe:924): Pango-WARNING **: Invalid UTF-8 string passed to pango_layout_set_text()
#
# (dot.exe:924): Pango-WARNING **: Invalid UTF-8 string passed to pango_layout_set_text()
#
# (dot.exe:924): Pango-WARNING **: Invalid UTF-8 string passed to pango_layout_set_text()
#
# (dot.exe:924): Pango-WARNING **: Invalid UTF-8 string passed to pango_layout_set_text()
