# %% [markdown]
# # NER Training Data Creation (Training-based)

# %%
def para_to_text(p):
    """
    A function to find every texts in the paragraph

    params
    ----
    p : docx.Document.Paragraph object

    returns
    ----
    str 

    """
    rs = p._element.xpath(".//w:t")
    return u"".join([r.text for r in rs])


def sop_to_text(file_path):
    """
    Converts SOP.docx into plain text

    params
    ----
    file_path : str (path to the SOP document) 

    returns
    ----
    str
    """
    text = []
    with open(file_path, 'rb') as f:
        source_stream = BytesIO(f.read())
    f.close()

    doc = Document(source_stream)
    paras = doc.paragraphs
    for p in paras:
        text.append(para_to_text(p))
            
    text = " ".join(text).strip()
    return text

# %% [markdown]
# #### Spacy requires training data to be in the following format:

# %% [markdown]
# ```python
#
# train_data = [
#
#     ("SENTENCES BLABLABLA", {entities : [(entity start index, entity end index, "LABEL A"),
#                                          (entity start index, entity end index, "LABEL B")]})
#
#
# ]
#
# ```

# %% [markdown]
# # Event type entity training (Rule-based)

# %%
import os
import json
from docx import Document
from io import StringIO, BytesIO
import re

# %%
path = "/Users/Public/Desktop/SOPs/"
SOPs = os.listdir(path)

# %%
events = []
code_pattern = r"^[A-Z0-9][A-Z0-9]+[\- ]+.+"
for sop in SOPs:
    filepath = path+sop
    with open(filepath, 'rb') as f:
        source_stream = BytesIO(f.read())
    f.close()
    doc = Document(source_stream)
    paras = doc.paragraphs
    for p in paras:
        style = p.style.name
        text = para_to_text(p)
        
        if "Normal" in style:
            code = text.split(" event type")[0].split("for the ")[-1]
            r = re.findall(code_pattern, code)
            if r:
                events.append(r[0])

# %%
raw_event_list = []
event_code = []
pattern = r"[A-Z0-9][A-Z0-9]+"
inconsistency = set()
for sop in SOPs:
    event_des = "".join(sop.split("-")[1:]).strip().split(".")[0]
    raw_event_list.append(event_des)
    
    p = re.findall(pattern, event_des)
    if p:
        event_code.append(p[0])
    else:
        event_code.append(event_des)

# %%
list(set(event_code))
# Out:
# ['Bylaw',
#  'MISSIC',
#  'Misch',
#  'MARINE',
#  'SUSPC',
#  'PARK',
#  'ROBBI',
#  'MVI12345',
#  'AIREM',
#  'SCOLL',
#  'FIREAR',
#  'MISCH',
#  'ALRM123',
#  'ASSOA',
#  'BYLAW',
#  'DEMON',
#  'WEAPON',
#  'RECVEH',
#  '1033',
#  'ALARM',
#  'SIP',
#  'PROP',
#  'DNA',
#  'GAS1234',
#  'CHECK',
#  'FRAUD',
#  'TRAFF',
#  'ABDUC',
#  'NOK',
#  'WARRAN',
#  'WIRE12',
#  'RES123M',
#  'COUNTERFEIT',
#  'THEFTV',
#  'INDEC',
#  'EXP123',
#  'PANHA',
#  'ANNOY',
#  'EXPLOS',
#  'ELEC12',
#  'MED12A',
#  'RUBSH',
#  'ASLT',
#  'HAZARD',
#  'MVIHR',
#  'TEST',
#  'ACF',
#  'MVIINJ',
#  'BNEI',
#  '911',
#  'ASLTSX',
#  'MVI',
#  'ASSPFA',
#  'HARASS',
#  'Theft',
#  'KPEACE',
#  'PURSUE',
#  'STOVE',
#  'ROBB',
#  'SPAT',
#  'SHOTS',
#  'ARREST',
#  'BAIT',
#  'SHOPL',
#  'PROST',
#  'AB911',
#  'HOMEIN',
#  'INTELL',
#  'BOMB',
#  'BAITB',
#  'THEFTI',
#  'MUAID',
#  'SCREAM',
#  'ALARMS',
#  'ALARMH',
#  'THEFT',
#  'MISCHI',
#  'WILD123',
#  'ACRA',
#  'DOMRPT',
#  'STALK',
#  'TRAFFS',
#  'SUICID',
#  'ASSGP',
#  'THREATS',
#  'FOUNDP',
#  'COUNT',
#  'SUDDEN',
#  'FIGHT',
#  'ASLTI',
#  'PROWL',
#  'MAND',
#  'STAFF',
#  'VAULT',
#  'ILBRN',
#  'BORDR',
#  'EXTORT',
#  'SUSPP',
#  'ASIST',
#  'SCOB',
#  'JUMPER',
#  'DRUGS',
#  'ABANDV',
#  'DOMI',
#  'POLE',
#  'PREV',
#  'INDUST',
#  'YOUTH',
#  'ANIMAL',
#  'VEF123',
#  'HAZM123',
#  'ARSON',
#  'OVERD',
#  'WATER',
#  'MISSIP',
#  'MVIPOL',
#  'BNE',
#  'IMPAIR',
#  'BREACH',
#  'OCC',
#  'Pursue',
#  'ALARMA',
#  'LIQUOR',
#  'FBOAT',
#  'ACEM',
#  'SHIP123',
#  'SMK123',
#  'ALARMD',
#  'BBQF',
#  'ST123',
#  'MUNI',
#  'CHIM',
#  'ODOUU',
#  'UNWANT',
#  'SUSPV',
#  'HOSTAG',
#  'ASSMHA',
#  'DISTB',
#  'INSEC']

# %%
events
# Out:
# ['1033 – Officer in trouble',
#  '911 – Any police call',
#  'AB911 – Abandoned and Accidental 911 cellular phone calls',
#  'AB911 – Abandoned and Accidental 911 landline phone calls',
#  'ABANDV - Abandoned vehicle',
#  'ABANDV - Abandoned vehicle',
#  'ABDUC – Abduction',
#  'AIREM – Air Emergency',
#  'ALARMD – Domestic Violence Emergency Response System Alarm (DVERS)',
#  'ALARMH – Hold up alarm',
#  'ALARMS – Silent or Panic Alarm',
#  'ARSON – Arson',
#  'ASLT – Assault',
#  'ASLTI – Assault in Progress',
#  'ASSGP – Assist General Public',
#  'ASSMHA – Assist Mental Health Act',
#  'ASSOA – Assist Other Agency',
#  'BAIT – Bait Car Activations',
#  'BNEI – Break and enter in progress',
#  'BOMB – Bomb Threats',
#  'BORDR – Border Runner',
#  'BREACH – Breach of conditions, undertaking or restraining order',
#  'BYLAW - Bylaws',
#  'CHECK - Check wellbeing',
#  'COUNT – Counterfeit Currency',
#  'DEMON - Demonstration',
#  'DISTB – Disturbance',
#  'DOMRPT - Domestic report',
#  'DRUGS – Drugs',
#  'EXPLOS – Explosion/Explosive',
#  'EXTORT – Extortion',
#  'FIGHT – Fight',
#  'FIREAR – Firearm for Pickup/ Transport',
#  'FOUNDP – Found Person',
#  'HARASS - Harassment',
#  'HAZARD – Hazardous situations',
#  'HOMEIN – Home Invasion',
#  'HOSTAG – Hostage Situation',
#  'IMPAIR – Impaired Driver',
#  'INDEC – Indecent Act',
#  'INDUST – Industrial Accident',
#  'INSEC – Insecure Premises/Vehicles',
#  'JUMPER – Jumper',
#  'KPEACE – Keep the Peace',
#  'LIQUOR – Liquor Act/ Licensed Premises Check',
#  'MAND – Man Down',
#  'MARINE – Marine Incident',
#  'MISCH – Mischief',
#  'MISCH – Mischief',
#  'MISCHI – Mischief',
#  'MISSIP – Missing person',
#  'MVI – Motor Vehicle Incident',
#  'MVIHR – Hit and Run',
#  'MVIINJ – Motor Vehicle Incident with Injuries',
#  'MVIPOL – MVI with Police vehicle',
#  'NOK – Next of kin notification',
#  'OCC – Other Criminal Code',
#  'OVERD – Overdose',
#  'PANHA – Panhandler',
#  'PARK - Parking complaint',
#  'PROP – Property',
#  'PROP – Property lost, found or seized',
#  'PROST – Prostitution',
#  'PROWL – Prowler',
#  'PURSUE – Pursuit',
#  'RECVEH – Recovered Vehicle',
#  'RECVEH – Recovered stolen vehicle',
#  'ROBB – Robbery with a time delay,',
#  'ROBBI – Robbery in progress',
#  'SUICID – Suicidal person',
#  'SUSPP – Suspicious Person',
#  'THEFT – Theft',
#  'THEFTI – Theft in Progress',
#  'THEFTV – Theft of Vehicle',
#  'THEFTV – Theft of vehicle',
#  'TRAFF – Traffic Incident',
#  'TRAFF – Traffic Incident',
#  'TRAFFS – Traffic suspension 215s and Immediate Roadside Prohibitions',
#  'UNWANT – Unwanted person',
#  'WARRAN - Warrant',
#  '1033 – Officer in trouble',
#  '911 – Any police call',
#  'AB911 – Abandoned and Accidental 911 cellular phone calls',
#  'AB911 – Abandoned and Accidental 911 landline phone calls',
#  'ABANDV - Abandoned vehicle',
#  'ABDUC – Abduction',
#  'ALARMD – Domestic Violence Emergency Response System Alarm (DVERS)',
#  'ALARMH – Hold up alarm',
#  'ANIMAL – Animal',
#  'ARSON – Arson',
#  'ASLT – Assault',
#  'ASLTI – Assault in Progress',
#  'ASLTSX – Sexual Assault',
#  'ASSGP – Assist General Public',
#  'ASSMHA – Assist Mental Health Act',
#  'ASSOA – Assist Other Agency',
#  'ASSPFA – Assist Police Fire Ambulance',
#  'BAIT – Bait Car Activations',
#  'BNEI – Break and enter in progress',
#  'BOMB – Bomb Threats',
#  'BREACH – Breach of conditions, undertaking or restraining order',
#  'BYLAW - Bylaws',
#  'CHECK - Check wellbeing',
#  'COUNT – Counterfeit Currency',
#  'DEMON - Demonstration',
#  'DISTB – Disturbance',
#  'DNA - DNA collection requests',
#  'DOMI – Domestic in Progress',
#  'DOMRPT - Domestic report',
#  'DRUGS – Drugs',
#  'DRUGS – Drugs',
#  'EXPLOS – Explosion/Explosive',
#  'EXTORT – Extortion',
#  'FIGHT – Fight',
#  'FIREAR – Firearm for Pickup/ Transport',
#  'FOUNDP – Found Person',
#  'HARASS - Harassment',
#  'HAZARD – Hazardous situations',
#  'HOMEIN – Home Invasion',
#  'HOSTAG – Hostage Situation',
#  'IMPAIR – Impaired Driver',
#  'INDEC – Indecent Act',
#  'INDUST – Industrial Accident',
#  'INSEC – Insecure Premises/Vehicles',
#  'JUMPER – Jumper',
#  'KPEACE – Keep the Peace',
#  'LIQUOR – Liquor Act/ Licensed Premises Check',
#  'MAND – Man Down',
#  'MARINE – Marine Incident',
#  'MISCH – Mischief',
#  'MISCHI – Mischief',
#  'MISSIP – Missing person',
#  'MVI – Motor Vehicle Incident',
#  'MVIHR – Hit and Run',
#  'MVIINJ – Motor Vehicle Incident with Injuries',
#  'MVIPOL – MVI with Police vehicle',
#  'NOK – Next of kin notification',
#  'OCC – Other Criminal Code',
#  'OVERD – Overdose',
#  'PANHA – Panhandler',
#  'PARK - Parking complaint',
#  'PROP – Property',
#  'PROP – Property lost, found or seized',
#  'PROST – Prostitution',
#  'PROWL – Prowler',
#  'PURSUE – Pursuit',
#  'RECVEH – Recovered Vehicle',
#  'SUSPP – Suspicious Person',
#  'RECVEH – Recovered stolen vehicle',
#  'ROBB – Robbery with a time delay,',
#  'ROBBI – Robbery in progress',
#  'SUICID – Suicidal person',
#  'THEFT – Theft',
#  'THEFTI – Theft in Progress',
#  'THEFTV – Theft of Vehicle',
#  'THEFTV – Theft of vehicle',
#  'TRAFF – Traffic Incident',
#  'TRAFFS – Traffic suspension 215s and Immediate Roadside Prohibitions',
#  'UNWANT – Unwanted person',
#  'WARRAN - Warrant',
#  '1033 – Officer in trouble',
#  '911 – Any police call',
#  'AB911 – Abandoned and Accidental 911 cellular phone calls',
#  'AB911 – Abandoned and Accidental 911 landline phone calls',
#  'ABANDV - Abandoned vehicle',
#  'ABDUC – Abduction',
#  'ALARMD – Domestic Violence Emergency Response System Alarm (DVERS)',
#  'ALARMH – Hold up alarm',
#  'ARSON – Arson',
#  'ASLT – Assault',
#  'ASLTI – Assault in Progress',
#  'ASLTSX – Sexual Assault',
#  'ASSGP – Assist General Public',
#  'ASSMHA – Assist Mental Health Act',
#  'ASSOA – Assist Other Agency',
#  'ASSPFA – Assist Police Fire Ambulance',
#  'BAIT – Bait Car Activations',
#  'BNEI – Break and enter in progress',
#  'BOMB – Bomb Threats',
#  'BREACH – Breach of conditions, undertaking or restraining order',
#  'BYLAW - Bylaws',
#  'CHECK - Check wellbeing',
#  'COUNT – Counterfeit Currency',
#  'DEMON - Demonstration',
#  'DISTB – Disturbance',
#  'DNA - DNA collection requests',
#  'DOMRPT - Domestic report',
#  'DRUGS – Drugs',
#  'DRUGS – Drugs',
#  'EXPLOS – Explosion/Explosive',
#  'EXTORT – Extortion',
#  'FIGHT – Fight',
#  'FIREAR – Firearm for Pickup/ Transport',
#  'FOUNDP – Found Person',
#  'HARASS - Harassment',
#  'HAZARD – Hazardous situations',
#  'HOMEIN – Home Invasion',
#  'HOSTAG – Hostage Situation',
#  'IMPAIR – Impaired Driver',
#  'INDEC – Indecent Act',
#  'INDUST – Industrial Accident',
#  'INSEC – Insecure Premises/Vehicles',
#  'JUMPER – Jumper',
#  'KPEACE – Keep the Peace',
#  'LIQUOR – Liquor Act/ Licensed Premises Check',
#  'MAND – Man Down',
#  'MARINE – Marine Incident',
#  'MISCH – Mischief',
#  'MISCH – Mischief',
#  'MISCHI – Mischief',
#  'MISSIP – Missing person',
#  'MVI – Motor Vehicle Incident',
#  'MVIHR – Hit and Run',
#  'MVIINJ – Motor Vehicle Incident with Injuries',
#  'MVIPOL – MVI with Police vehicle',
#  'NOK – Next of kin notification',
#  'OCC – Other Criminal Code',
#  'OVERD – Overdose',
#  'PANHA – Panhandler',
#  'PARK - Parking complaint',
#  'PROP – Property',
#  'PROP – Property lost, found or seized',
#  'PROST – Prostitution',
#  'PROWL – Prowler',
#  'PURSUE – Pursuit',
#  'RECVEH – Recovered Vehicle',
#  'SUSPP – Suspicious Person',
#  'RECVEH – Recovered stolen vehicle',
#  'ROBB – Robbery with a time delay,',
#  'ROBBI – Robbery in progress',
#  'SUICID – Suicidal person',
#  'THEFT – Theft',
#  'THEFTI – Theft in Progress',
#  'THEFTV – Theft of Vehicle',
#  'THEFTV – Theft of vehicle',
#  'TRAFF – Traffic Incident',
#  'UNWANT – Unwanted person',
#  'WARRAN - Warrant',
#  'ACEM – Aircraft emergency landing',
#  'ACF – Aircraft Fire',
#  'BBQF – Barbecue Fire',
#  'BOMB – Bomb threat',
#  'CHIM – Chimney fire',
#  'EXP 1/2/3 – Explosion',
#  'ILBRN – Illegal burn',
#  'MUAID – Mutual aid',
#  'ODOUU call type – Odour source unknown',
#  'POLE- Pole Fire',
#  'PREV - Fire prevention',
#  'RES 1/2/3/M – Rescue',
#  'RUBSH – Rubbish',
#  'SCOLL – Structure collapse',
#  'TEST – Test call',
#  'VAULT – Electrical vault fire',
#  'VEF 1/2/3 – Vehicle fire',
#  'WATER – Water problem',
#  '1033 – Officer in trouble',
#  '911 – Any police call',
#  'AB911 – Abandoned and Accidental 911 cellular phone calls',
#  'AB911 – Abandoned and Accidental 911 landline phone calls',
#  'ABANDV - Abandoned vehicle',
#  'ABDUC – Abduction',
#  'ACF – Aircraft Fire',
#  'AIREM – Air Emergency',
#  'ALARMD – Domestic Violence Emergency Response System Alarm (DVERS)',
#  'ALARMH – Hold up alarm',
#  'ALARMS – Silent or Panic Alarm',
#  'ARSON – Arson',
#  'ASLT – Assault',
#  'ASLTI – Assault in Progress',
#  'ASSGP – Assist General Public',
#  'ASSMHA – Assist Mental Health Act',
#  'ASSOA – Assist Other Agency',
#  'BAIT – Bait Car Activations',
#  'BBQF – Barbecue Fire',
#  'BNEI – Break and enter in progress',
#  'BOMB – Bomb Threats',
#  'BOMB – Bomb threat',
#  'BORDR – Border Runner',
#  'BREACH – Breach of conditions, undertaking or restraining order',
#  'BYLAW - Bylaws',
#  'CHECK - Check wellbeing',
#  'CHIM – Chimney fire',
#  'COUNT – Counterfeit Currency',
#  'DEMON - Demonstration',
#  'DISTB – Disturbance',
#  'DNA - DNA collection requests',
#  'DOMRPT - Domestic report',
#  'DRUGS – Drugs',
#  'DRUGS – Drugs',
#  'EXP 1/2/3 – Explosion',
#  'EXPLOS – Explosion/Explosive',
#  'EXTORT – Extortion',
#  'FIGHT – Fight',
#  'FIREAR – Firearm for Pickup/ Transport',
#  'FOUNDP – Found Person',
#  'GAS 1/2/3/4 – Compressed gas leak',
#  'HARASS - Harassment',
#  'HAZARD – Hazardous situations',
#  'HOMEIN – Home Invasion',
#  'HOSTAG – Hostage Situation',
#  'ILBRN – Illegal burn',
#  'IMPAIR – Impaired Driver',
#  'INDEC – Indecent Act',
#  'INDUST – Industrial Accident',
#  'INSEC – Insecure Premises/Vehicles',
#  'JUMPER – Jumper',
#  'KPEACE – Keep the Peace',
#  'LIQUOR – Liquor Act/ Licensed Premises Check',
#  'MAND – Man Down',
#  'MARINE – Marine Incident',
#  'MISCH – Mischief',
#  'MISCHI – Mischief',
#  'MISSIP – Missing person',
#  'MUAID – Mutual aid',
#  'MVI – Motor Vehicle Incident',
#  'MVIHR – Hit and Run',
#  'MVIINJ – Motor Vehicle Incident with Injuries',
#  'MVIPOL – MVI with Police vehicle',
#  'NOK – Next of kin notification',
#  'OCC – Other Criminal Code',
#  'ODOUU call type – Odour source unknown',
#  'OVERD – Overdose',
#  'PANHA – Panhandler',
#  'PARK - Parking complaint',
#  'POLE- Pole Fire',
#  'PREV - Fire prevention',
#  'PROP – Property',
#  'PROP – Property lost, found or seized',
#  'PROST – Prostitution',
#  'PROWL – Prowler',
#  'PURSUE – Pursuit',
#  'RECVEH – Recovered Vehicle',
#  'SUSPP – Suspicious Person',
#  'RECVEH – Recovered stolen vehicle',
#  'RES 1/2/3/M – Rescue',
#  'ROBB – Robbery with a time delay,',
#  'ROBBI – Robbery in progress',
#  'RUBSH – Rubbish',
#  'SCOLL – Structure collapse',
#  'SUICID – Suicidal person',
#  'TEST – Test call',
#  'THEFT – Theft',
#  'THEFTI – Theft in Progress',
#  'THEFTV – Theft of Vehicle',
#  'THEFTV – Theft of vehicle',
#  'TRAFF – Traffic Incident',
#  'TRAFFS – Traffic suspension 215s and Immediate Roadside Prohibitions',
#  'UNWANT – Unwanted person',
#  'VAULT – Electrical vault fire',
#  'VEF 1/2/3 – Vehicle fire',
#  'WARRAN - Warrant',
#  'WATER – Water problem',
#  'ASSPFA – Assist Police Fire Ambulance',
#  'THEFTV – Theft of Vehicle',
#  '1033 – Officer in trouble',
#  '911 – Any police call',
#  'ABANDV - Abandoned vehicle',
#  'ASSOA – Assist Other Agency',
#  'DRUGS – Drugs',
#  'FOUNDP – Found Person',
#  'HAZARD – Hazardous situations',
#  'IMPAIR – Impaired Driver',
#  'INSEC – Insecure Premises/Vehicles',
#  'JUMPER – Jumper',
#  'MAND – Man Down',
#  'MISCH – Mischief',
#  'MISCHI – Mischief',
#  'MVI – Motor Vehicle Incident',
#  'MVIHR – Hit and Run',
#  'MVIINJ – Motor Vehicle Incident with Injuries',
#  'MVIPOL – MVI with Police vehicle',
#  'OCC – Other Criminal Code',
#  'PANHA – Panhandler',
#  'PARK - Parking complaint',
#  'PROP – Property lost, found or seized',
#  'PURSUE – Pursuit',
#  'SUSPP – Suspicious Person',
#  'RECVEH – Recovered stolen vehicle',
#  'SUICID – Suicidal person',
#  'THEFTV – Theft of vehicle',
#  'TRAFF – Traffic Incident',
#  'TRAFFS – Traffic suspension 215s and Immediate Roadside Prohibitions',
#  'AB911 – Abandoned and Accidental 911 landline phone calls',
#  '1033 Officer in trouble',
#  '911 Police – Any Call',
#  'AB911 – Abandoned and Accidental 911 cellular phone calls',
#  'ABANDV - Abandoned vehicle',
#  'ABDUC – Abduction',
#  'AIREM – Air Emergency',
#  'ALARM – Audible alarm',
#  'ALARMA Airport Check Point',
#  'ALARMD Domestic Violence Emergency Response System Alarm (DVERS)',
#  'ALARMH Alarm Hold Up',
#  'ALARMS Alarm Silent / Panic',
#  'ARREST Arrest',
#  'ARSON Arson',
#  'ASLT Assault',
#  'ASLTI – Assault in Progress',
#  'ASSGP – Assist General Public',
#  'ASSMHA – Assist Mental Health Act',
#  'ASSOA – Assist Other Agency',
#  'BAIT Bait Car Activated',
#  'BNEI – Break and enter in progress',
#  'BOMB – Bomb Threats',
#  'BORDR – Border Runner',
#  'BREACH – Breach of conditions, undertaking or restraining order',
#  'BYLAW - Bylaws',
#  'BYLAW - Bylaws',
#  'BYLAW - Bylaws',
#  'CHECK - Check wellbeing',
#  'COUNT – Counterfeit Currency',
#  'DEMON - Demonstration',
#  'DISTB – Disturbance',
#  'DNA - DNA collection requests',
#  'DOMRPT - Domestic report',
#  'DRUGS – Drugs',
#  'EXPLOS – Explosion/Explosive',
#  'EXTORT – Extortion',
#  'FIGHT – Fight',
#  'FIREAR – Firearm for Pickup/ Transport',
#  'FOUNDP – Found Person',
#  'HARASS - Harassment',
#  'HAZARD – Hazardous situations',
#  'HOMEIN – Home Invasion',
#  'HOSTAG – Hostage Situation',
#  'IMPAIR – Impaired Driver',
#  'INDEC – Indecent Act',
#  'INDUST – Industrial Accident',
#  'INSEC – Insecure Premises/Vehicles',
#  'JUMPER – Jumper',
#  'KPEACE – Keep the Peace',
#  'LIQUOR – Liquor Act/ Licensed Premises Check',
#  'MAND – Man Down',
#  'MARINE – Marine Incident',
#  'MISCH – Mischief',
#  'MISCHI – Mischief',
#  'MISSIP – Missing person',
#  'MVI – Motor Vehicle Incident',
#  'MVIHR – Hit and Run',
#  'MVIHR – Hit and Run',
#  'MVIHR – Hit and Run',
#  'MVIINJ – Motor Vehicle Incident with Injuries',
#  'MVIPOL – MVI with Police vehicle',
#  'NOK – Next of kin notification',
#  'OCC – Other Criminal Code',
#  'OVERD – Overdose',
#  'PANHA – Panhandler',
#  'PARK - Parking complaint',
#  'PARK - Parking complaint',
#  'PARK - Parking complaint',
#  'PROP – Property',
#  'PROST – Prostitution',
#  'PROWL – Prowler',
#  'PURSUE – Pursuit',
#  'RECVEH – Recovered stolen vehicle',
#  'ROBB – Robbery with a time delay,',
#  'ROBBI – Robbery in progress',
#  'SPATT – Special Attention to Detail Event type.',
#  'SUICID – Suicidal person',
#  'THEFTI – Theft in Progress',
#  'THEFTV – Theft of vehicle',
#  'TRAFF – Traffic Incident',
#  'TRAFFS – Traffic suspension 215s and Immediate Roadside Prohibitions',
#  'UNWANT – Unwanted person',
#  'WARRAN - Warrant',
#  'ACF – Aircraft Fire',
#  'ALRM 1/2/3 – Fire Alarm',
#  'BBQF – Barbecue Fire',
#  'BOMB – Bomb threat',
#  'CHIM – Chimney fire',
#  'EXP 1/2/3 – Explosion',
#  'GAS 1/2/3/4 – Compressed gas leak',
#  'ILBRN – Illegal burn',
#  'MUAID – Mutual aid',
#  'ODOUU call type – Odour source unknown',
#  'POLE- Pole Fire',
#  'PREV - Fire prevention',
#  'RES 1/2/3/M – Rescue',
#  'RUBSH – Rubbish',
#  'SCOLL – Structure collapse',
#  'TEST – Test call',
#  'VAULT – Electrical vault fire',
#  'VEF 1/2/3 – Vehicle fire',
#  'MUNI – Municipal works',
#  '1033 – Officer in trouble',
#  '911 – Any police call',
#  'AB911 – Abandoned and Accidental 911 cellular phone calls',
#  'AB911 – Abandoned and Accidental 911 landline phone calls',
#  'ABANDV - Abandoned vehicle',
#  'ABDUC – Abduction',
#  'ACF – Aircraft Fire',
#  'ALARMD – Domestic Violence Emergency Response System Alarm (DVERS)',
#  'ALARMH – Hold up alarm',
#  'ARSON – Arson',
#  'ASLT – Assault',
#  'ASLTI – Assault in Progress',
#  'ASLTSX – Sexual Assault',
#  'ASSGP – Assist General Public',
#  'ASSMHA – Assist Mental Health Act',
#  'ASSOA – Assist Other Agency',
#  'ASSPFA – Assist Police Fire Ambulance',
#  'BAIT – Bait Car Activations',
#  'BBQF – Barbecue Fire',
#  'BNEI – Break and enter in progress',
#  'BOMB – Bomb Threats',
#  'BOMB – Bomb threat',
#  'BREACH – Breach of conditions, undertaking or restraining order',
#  'BYLAW - Bylaws',
#  'CHECK - Check wellbeing',
#  'CHIM – Chimney fire',
#  'COUNT – Counterfeit Currency',
#  'DEMON - Demonstration',
#  'DISTB – Disturbance',
#  'DNA - DNA collection requests',
#  'DOMRPT - Domestic report',
#  'DRUGS – Drugs',
#  'DRUGS – Drugs',
#  'EXP 1/2/3 – Explosion',
#  'EXPLOS – Explosion/Explosive',
#  'EXTORT – Extortion',
#  'FIGHT – Fight',
#  'FIREAR – Firearm for Pickup/ Transport',
#  'FOUNDP – Found Person',
#  'GAS 1/2/3/4 – Compressed gas leak',
#  'HARASS - Harassment',
#  'HAZARD – Hazardous situations',
#  'HOMEIN – Home Invasion',
#  'HOSTAG – Hostage Situation',
#  'ILBRN – illegal burn',
#  'IMPAIR – Impaired Driver',
#  'INDEC – Indecent Act',
#  'INDUST – Industrial Accident',
#  'INSEC – Insecure Premises/Vehicles',
#  'JUMPER – Jumper',
#  'KPEACE – Keep the Peace',
#  'LIQUOR – Liquor Act/ Licensed Premises Check',
#  'MAND – Man Down',
#  'MARINE – Marine Incident',
#  'MISCH – Mischief',
#  'MISCHI – Mischief',
#  'MISSIP – Missing person',
#  'MUAID – Mutual aid',
#  'MVI – Motor Vehicle Incident',
#  'MVIHR – Hit and Run',
#  'MVIINJ – Motor Vehicle Incident with Injuries',
#  'MVIPOL – MVI with Police vehicle',
#  'NOK – Next of kin notification',
#  'OCC – Other Criminal Code',
#  'ODOUU call type – Odour source unknown',
#  'OVERD – Overdose',
#  'PANHA – Panhandler',
#  'PARK - Parking complaint',
#  'POLE- Pole Fire',
#  'PREV - Fire prevention',
#  'PROP – Property',
#  'PROP – Property lost, found or seized',
#  'PROST – Prostitution',
#  'PROWL – Prowler',
#  'PURSUE – Pursuit',
#  'RECVEH – Recovered Vehicle',
#  'SUSPP – Suspicious Person',
#  'RECVEH – Recovered stolen vehicle',
#  'RES 1/2/3/M – Rescue',
#  'ROBB – Robbery with a time delay,',
#  'ROBBI – Robbery in progress',
#  'RUBSH – Rubbish',
#  'SCOLL – Structure collapse',
#  'SUICID – Suicidal person',
#  'TEST – Test call',
#  'THEFT – Theft',
#  'CCJS the GO',
#  'CCJS the GO',
#  'THEFTI – Theft in Progress',
#  'THEFTV – Theft of Vehicle',
#  'THEFTV – Theft of vehicle',
#  'TRAFF – Traffic Incident',
#  'UNWANT – Unwanted person',
#  'VAULT – Electrical vault fire',
#  'VEF 1/2/3 – Vehicle fire',
#  'WARRAN - Warrant',
#  'WATER – Water problem',
#  '1033 – Officer in trouble',
#  '911 – Any police call',
#  'AB911 – Abandoned and Accidental 911 cellular phone calls',
#  'AB911 – Abandoned and Accidental 911 landline phone calls',
#  'ABANDV - Abandoned vehicle',
#  'ABDUC – Abduction',
#  'ACF – Aircraft Fire',
#  'ALARMD – Domestic Violence Emergency Response System Alarm (DVERS)',
#  'ALARMH – Hold up alarm',
#  'ARSON – Arson',
#  'ASLT – Assault',
#  'ASLTI – Assault in Progress',
#  'ASLTSX – Sexual Assault',
#  'ASSGP – Assist General Public',
#  'ASSMHA – Assist Mental Health Act',
#  'ASSOA – Assist Other Agency',
#  'ASSPFA – Assist Police Fire Ambulance',
#  'BAIT – Bait Car Activations',
#  'BBQF – Barbecue Fire',
#  'BNEI – Break and enter in progress',
#  'BOMB – Bomb Threats',
#  'BOMB – Bomb threat',
#  'BREACH – Breach of conditions, undertaking or restraining order',
#  'BYLAW - Bylaws',
#  'CHECK - Check wellbeing',
#  'CHIM – Chimney fire',
#  'COUNT – Counterfeit Currency',
#  'DEMON - Demonstration',
#  'DISTB – Disturbance',
#  'DNA - DNA collection requests',
#  'DOMRPT - Domestic report',
#  'DRUGS – Drugs',
#  'EXP 1/2/3 – Explosion',
#  'EXPLOS – Explosion/Explosive',
#  'EXTORT – Extortion',
#  'FIGHT – Fight',
#  'FIREAR – Firearm for Pickup/ Transport',
#  'FOUNDP – Found Person',
#  'GAS 1/2/3/4 – Compressed gas leak',
#  'HARASS - Harassment',
#  'HAZARD – Hazardous situations',
#  'HOMEIN – Home Invasion',
#  'HOSTAG – Hostage Situation',
#  'ILBRN – illegal burn',
#  'IMPAIR – Impaired Driver',
#  'INDEC – Indecent Act',
#  'INDUST – Industrial Accident',
#  'INSEC – Insecure Premises/Vehicles',
#  'JUMPER – Jumper',
#  'KPEACE – Keep the Peace',
#  'LIQUOR – Liquor Act/ Licensed Premises Check',
#  'MAND – Man Down',
#  'MARINE – Marine Incident',
#  'MISCH – Mischief',
#  'MISCHI – Mischief',
#  'MISSIP – Missing person',
#  'MUAID – Mutual aid',
#  'MVI – Motor Vehicle Incident',
#  'MVIHR – Hit and Run',
#  'MVIINJ – Motor Vehicle Incident with Injuries',
#  'MVIPOL – MVI with Police vehicle',
#  'NOK – Next of kin notification',
#  'OCC – Other Criminal Code',
#  'ODOUU call type – Odour source unknown',
#  'OVERD – Overdose',
#  'PANHA – Panhandler',
#  'PARK - Parking complaint',
#  'POLE- Pole Fire',
#  'PREV - Fire prevention',
#  'PROP – Property',
#  'PROP – Property lost, found or seized',
#  'PROST – Prostitution',
#  'PROWL – Prowler',
#  'PURSUE – Pursuit',
#  'RECVEH – Recovered Vehicle',
#  'SUSPP – Suspicious Person',
#  'RECVEH – Recovered stolen vehicle',
#  'RES 1/2/3/M – Rescue',
#  'ROBB – Robbery with a time delay,',
#  'ROBBI – Robbery in progress',
#  'RUBSH – Rubbish',
#  'SCOLL – Structure collapse',
#  'STOVE – STOVE',
#  'SUICID – Suicidal person',
#  'TEST – Test call',
#  'THEFT – Theft',
#  'THEFTI – Theft in Progress',
#  'THEFTV – Theft of Vehicle',
#  'THEFTV – Theft of vehicle',
#  'TRAFF – Traffic Incident',
#  'TRAFFS – Traffic suspension 215s and Immediate Roadside Prohibitions',
#  'UNWANT – Unwanted person',
#  'VAULT – Electrical vault fire',
#  'VEF 1/2/3 – Vehicle fire',
#  'WARRAN - Warrant',
#  'WATER – Water problem',
#  'MUAID – Mutual aid',
#  '1033 – Officer in trouble',
#  '911 – Any police call',
#  'AB911 – Abandoned and Accidental 911 cellular phone calls',
#  'AB911 – Abandoned and Accidental 911 landline phone calls',
#  'ABANDV - Abandoned vehicle',
#  'ABDUC – Abduction',
#  'ACEM – Aircraft emergency landing',
#  'ACF – Aircraft Fire',
#  'G4S Security (contracted through CATSA) will trigger the alarms when explosives, ammunition, weapons, or suspicious articles are detected during screening. Alarms will also be activated when a passenger makes a bomb statement or when there is an unruly passenger.',
#  'ALARMD – Domestic Violence Emergency Response System Alarm (DVERS)',
#  'ALARMH – Hold up alarm',
#  'ARSON – Arson',
#  'ASLT – Assault',
#  'ASLTI – Assault in Progress',
#  'ASLTSX – Sexual Assault',
#  'ASSGP – Assist General Public',
#  'ASSMHA – Assist Mental Health Act',
#  'ASSOA – Assist Other Agency',
#  'ASSPFA – Assist Police Fire Ambulance',
#  'BAIT – Bait Car Activations',
#  'BBQF – Barbecue Fire',
#  'BNEI – Break and enter in progress',
#  'BOMB – Bomb Threats',
#  'BOMB – Bomb threat',
#  'BREACH – Breach of conditions, undertaking or restraining order',
#  'BYLAW - Bylaws',
#  'CHECK - Check wellbeing',
#  'CHIM – Chimney fire',
#  'COUNT – Counterfeit Currency',
#  'DEMON - Demonstration',
#  'DISTB – Disturbance',
#  'DNA - DNA collection requests',
#  'DOMRPT - Domestic report',
#  'DRUGS – Drugs',
#  'DRUGS – Drugs',
#  'EXP 1/2/3 – Explosion',
#  'EXPLOS – Explosion/Explosive',
#  'EXTORT – Extortion',
#  'FIGHT – Fight',
#  'FIREAR – Firearm for Pickup/ Transport',
#  'FOUNDP – Found Person',
#  'GAS 1/2/3/4 – Compressed gas leak',
#  'HARASS - Harassment',
#  'HAZARD – Hazardous situations',
#  'HOMEIN – Home Invasion',
#  'HOSTAG – Hostage Situation',
#  'ILBRN – illegal burn',
#  'IMPAIR – Impaired Driver',
#  'INDEC – Indecent Act',
#  'INDUST – Industrial Accident',
#  'INSEC – Insecure Premises/Vehicles',
#  'JUMPER – Jumper',
#  'KPEACE – Keep the Peace',
#  'LIQUOR – Liquor Act/ Licensed Premises Check',
#  'MAND – Man Down',
#  'MARINE – Marine Incident',
#  'MISCH – Mischief',
#  'MISCH – Mischief',
#  'MISCHI – Mischief',
#  'MISSIP – Missing person',
#  'MVI – Motor Vehicle Incident',
#  'MVIHR – Hit and Run',
#  'MVIINJ – Motor Vehicle Incident with Injuries',
#  'MVIPOL – MVI with Police vehicle',
#  'NOK – Next of kin notification',
#  'OCC – Other Criminal Code',
#  'ODOUU call type – Odour source unknown',
#  'OVERD – Overdose',
#  'PANHA – Panhandler',
#  'PARK - Parking complaint',
#  'POLE- Pole Fire',
#  'PREV - Fire prevention',
#  'PROP – Property',
#  'PROP – Property lost, found or seized',
#  'PROST – Prostitution',
#  'PROWL – Prowler',
#  'PURSUE – Pursuit',
#  'RECVEH – Recovered Vehicle',
#  'RECVEH – Recovered stolen vehicle',
#  'RES 1/2/3/M – Rescue',
#  'ROBB – Robbery with a time delay,',
#  'ROBBI – Robbery in progress',
#  'RUBSH – Rubbish',
#  'SCOLL – Structure collapse',
#  'STOVE – STOVE',
#  'SUICID – Suicidal person',
#  'SUSPP – Suspicious Person',
#  'TEST – Test call',
#  'THEFT – Theft',
#  'THEFTI – Theft in Progress',
#  'THEFTV – Theft of Vehicle',
#  'THEFTV – Theft of vehicle',
#  'TRAFF – Traffic Incident',
#  'UNWANT – Unwanted person',
#  'VAULT – Electrical vault fire',
#  'VEF 1/2/3 – Vehicle fire',
#  'WARRAN - Warrant',
#  'WATER – Water problem',
#  '1033 – Officer in trouble',
#  '911 – Any police call',
#  'AB911 – Abandoned and Accidental 911 cellular phone calls',
#  'AB911 – Abandoned and Accidental 911 landline phone calls',
#  'ABANDV - Abandoned vehicle',
#  'ABDUC – Abduction',
#  'ALARMD – Domestic Violence Emergency Response System Alarm (DVERS)',
#  'ALARMH – Hold up alarm',
#  'ARSON – Arson',
#  'ASLT – Assault',
#  'ASLTI – Assault in Progress',
#  'ASLTSX – Sexual Assault',
#  'ASSGP – Assist General Public',
#  'ASSMHA – Assist Mental Health Act',
#  'ASSOA – Assist Other Agency',
#  'ASSPFA – Assist Police Fire Ambulance',
#  'BAIT – Bait Car Activations',
#  'BNEI – Break and enter in progress',
#  'BOMB – Bomb Threats',
#  'BREACH – Breach of conditions, undertaking or restraining order',
#  'BYLAW - Bylaws',
#  'CHECK - Check wellbeing',
#  'COUNT – Counterfeit Currency',
#  'DEMON - Demonstration',
#  'DISTB – Disturbance',
#  'DNA - DNA collection requests',
#  'DOMRPT - Domestic report',
#  'DRUGS – Drugs',
#  'DRUGS – Drugs',
#  'EXPLOS – Explosion/Explosive',
#  'EXTORT – Extortion',
#  'FIGHT – Fight',
#  'FIREAR – Firearm for Pickup/ Transport',
#  'FOUNDP – Found Person',
#  'HARASS - Harassment',
#  'HAZARD – Hazardous situations',
#  'HOMEIN – Home Invasion',
#  'HOSTAG – Hostage Situation',
#  'IMPAIR – Impaired Driver',
#  'INDEC – Indecent Act',
#  'INDUST – Industrial Accident',
#  'INSEC – Insecure Premises/Vehicles',
#  'JUMPER – Jumper',
#  'KPEACE – Keep the Peace',
#  'LIQUOR – Liquor Act/ Licensed Premises Check',
#  'MAND – Man Down',
#  'MARINE – Marine Incident',
#  'MISCH – Mischief',
#  'MISCHI – Mischief',
#  'MISSIP – Missing person',
#  'MVI – Motor Vehicle Incident',
#  'MVIHR – Hit and Run',
#  'MVIINJ – Motor Vehicle Incident with Injuries',
#  'MVIPOL – MVI with Police vehicle',
#  'NOK – Next of kin notification',
#  'OCC – Other Criminal Code',
#  'OVERD – Overdose',
#  'PANHA – Panhandler',
#  'PARK - Parking complaint',
#  'PROP – Property',
#  'PROP – Property lost, found or seized',
#  'PROST – Prostitution',
#  'PROWL – Prowler',
#  'PURSUE – Pursuit',
#  'RECVEH – Recovered Vehicle',
#  'SUSPP – Suspicious Person',
#  'RECVEH – Recovered stolen vehicle',
#  'ROBB – Robbery with a time delay,',
#  'ROBBI – Robbery in progress',
#  'SUICID – Suicidal person',
#  'THEFT – Theft',
#  'THEFTI – Theft in Progress',
#  'THEFTV – Theft of Vehicle',
#  'THEFTV – Theft of vehicle',
#  'TRAFF – Traffic Incident',
#  'UNWANT – Unwanted person',
#  'WARRAN - Warrant',
#  '1033 – Officer in trouble',
#  '911 – Any police call',
#  'AB911 – Abandoned and Accidental 911 cellular phone calls',
#  'AB911 – Abandoned and Accidental 911 landline phone calls',
#  'ABANDV - Abandoned vehicle',
#  'ABDUC – Abduction',
#  'ALARMD – Domestic Violence Emergency Response System Alarm (DVERS)',
#  'ALARMH – Hold up alarm',
#  'ANNOY – Annoying Circumstances',
#  'ARSON – Arson',
#  'ASLT – Assault',
#  'ASLTI – Assault in Progress',
#  'ASLTSX – Sexual Assault',
#  'ASSGP – Assist General Public',
#  'ASSMHA – Assist Mental Health Act',
#  'ASSOA – Assist Other Agency',
#  'ASSPFA – Assist Police Fire Ambulance',
#  'BAIT – Bait Car Activations',
#  'BNEI – Break and enter in progress',
#  'BOMB – Bomb Threats',
#  'BREACH – Breach of conditions, undertaking or restraining order',
#  'BYLAW - Bylaws',
#  'CHECK - Check wellbeing',
#  'COUNT – Counterfeit Currency',
#  'DEMON - Demonstration',
#  'DISTB – Disturbance',
#  'DNA - DNA collection requests',
#  'DOMRPT - Domestic report',
#  'DRUGS – Drugs',
#  'DRUGS – Drugs',
#  'EXPLOS – Explosion/Explosive',
#  'EXTORT – Extortion',
#  'FIGHT – Fight',
#  'FIREAR – Firearm for Pickup/ Transport',
#  'FOUNDP – Found Person',
#  'HARASS - Harassment',
#  'HAZARD – Hazardous situations',
#  'HOMEIN – Home Invasion',
#  'HOSTAG – Hostage Situation',
#  'IMPAIR – Impaired Driver',
#  'INDEC – Indecent Act',
#  'INDUST – Industrial Accident',
#  'INSEC – Insecure Premises/Vehicles',
#  'JUMPER – Jumper',
#  'KPEACE – Keep the Peace',
#  'LIQUOR – Liquor Act/ Licensed Premises Check',
#  'MAND – Man Down',
#  'MARINE – Marine Incident',
#  'MISCH – Mischief',
#  'MISCHI – Mischief',
#  'MISSIP – Missing person',
#  'MVI – Motor Vehicle Incident',
#  'MVIHR – Hit and Run',
#  'MVIINJ – Motor Vehicle Incident with Injuries',
#  'NOK – Next of kin notification',
#  'OCC – Other Criminal Code',
#  'OVERD – Overdose',
#  'PANHA – Panhandler',
#  'PARK - Parking complaint',
#  'PROP – Property',
#  'PROP – Property lost, found or seized',
#  'PROST – Prostitution',
#  'PROWL – Prowler',
#  'PURSUE – Pursuit',
#  'RECVEH – Recovered Vehicle',
#  'SUSPP – Suspicious Person',
#  'RECVEH – Recovered stolen vehicle',
#  'ROBB – Robbery with a time delay,',
#  'ROBBI – Robbery in progress',
#  'SUICID – Suicidal person',
#  'THEFT – Theft',
#  'THEFTI – Theft in Progress',
#  'THEFTV – Theft of Vehicle',
#  'THEFTV – Theft of vehicle',
#  'TRAFF – Traffic Incident',
#  'UNWANT – Unwanted person',
#  'WARRAN - Warrant',
#  'ACF – Aircraft Fire',
#  'ALRM 1/2/3 – Fire Alarm',
#  'BBQF – Barbecue Fire',
#  'BOMB – Bomb threat',
#  'CHIM – Chimney fire',
#  'EXP 1/2/3 – Explosion',
#  'GAS 1/2/3/4 – Compressed gas leak',
#  'HAZM – Hazardous Materials',
#  'ILBRN – illegal burn',
#  'MUAID – Mutual aid',
#  'ODOUU call type – Odour source unknown',
#  'POLE- Pole Fire',
#  'PREV - Fire prevention',
#  'RES 1/2/3/M – Rescue',
#  'RUBSH – Rubbish',
#  'SCOLL – Structure collapse',
#  'STOVE – STOVE',
#  'TEST – Test call',
#  'VAULT – Electrical vault fire',
#  'VEF 1/2/3 – Vehicle fire',
#  'WATER – Water problem',
#  'ACF – Aircraft Fire',
#  'ALRM 1/2/3 – Fire Alarm',
#  'BBQF – Barbecue Fire',
#  'BOMB – Bomb threat',
#  'CHIM – Chimney fire',
#  'EXP 1/2/3 – Explosion',
#  'GAS 1/2/3/4 – Compressed gas leak',
#  'HAZM – Hazardous Materials',
#  'ILBRN – illegal burn',
#  'MUAID – Mutual aid',
#  'MUNI – Municipal works',
#  'ODOUU call type – Odour source unknown',
#  'POLE- Pole Fire',
#  'PREV - Fire prevention',
#  'RES 1/2/3/M – Rescue',
#  'RUBSH – Rubbish',
#  'SCOLL – Structure collapse',
#  'STOVE – STOVE',
#  'TEST – Test call',
#  'VAULT – Electrical vault fire',
#  'VEF 1/2/3 – Vehicle fire',
#  'WATER – Water problem',
#  '1033 – Officer in trouble',
#  '911 – Any police call',
#  'AB911 – Abandoned and Accidental 911 cellular phone calls',
#  'AB911 – Abandoned and Accidental 911 landline phone calls',
#  'ABANDV - Abandoned vehicle',
#  'ABDUC – Abduction',
#  'ALARMD – Domestic Violence Emergency Response System Alarm (DVERS)',
#  'ALARMH – Hold up alarm',
#  'ARSON – Arson',
#  'ASLT – Assault',
#  'ASLTI – Assault in Progress',
#  'ASLTSX – Sexual Assault',
#  'ASSGP – Assist General Public',
#  'ASSMHA – Assist Mental Health Act',
#  'ASSOA – Assist Other Agency',
#  'ASSPFA – Assist Police Fire Ambulance',
#  'BAIT – Bait Car Activations',
#  'BNEI – Break and enter in progress',
#  'BOMB – Bomb Threats',
#  'BREACH – Breach of conditions, undertaking or restraining order',
#  'BYLAW - Bylaws',
#  'CHECK - Check wellbeing',
#  'COUNT – Counterfeit Currency',
#  'DEMON - Demonstration',
#  'DISTB – Disturbance',
#  'DNA - DNA collection requests',
#  ...]

# %%
pattern = r'^([A-Z]+)[ -]+([\w ]*)-([\w ,-]*).docx'
events_code = []
for sop in SOPs:
    match = re.findall(pattern, sop, re.IGNORECASE)
    event_parts = [x.strip() for x in list(filter(None, match[0][1:]))]
    events_code.extend(event_parts)
    events_code.append(" - ".join(event_parts))

# %%
import pandas as pd
df = pd.read_csv("../data/interim/sop_types_valid.csv")
df
# Out:
#       type                                               juri  \
# 0     1033  ['AB', 'BI', 'BU', 'DE', 'DFPF', 'NW', 'PO', '...
# 1     DOMI  ['AB', 'BI', 'BU', 'DE', 'DFPF', 'NW', 'PO', '...
# 2   FOUNDP  ['AB', 'BI', 'BU', 'DE', 'DFPF', 'NW', 'PO', '...
# 3   HAZARD  ['AB', 'BI', 'BU', 'DE', 'DFPF', 'NW', 'PO', '...
# 4   IMPAIR  ['AB', 'BI', 'BU', 'DE', 'DFPF', 'NW', 'PO', '...
# ..     ...                                                ...
# 92  INDUST  ['AB', 'BI', 'BU', 'DE', 'NW', 'PO', 'RI', 'RM...
# 93  ASSMHA  ['AB', 'BI', 'BU', 'DE', 'NW', 'PO', 'RI', 'RM...
# 94    SPAT  ['BI', 'BU', 'DE', 'NW', 'PO', 'RI', 'RM', 'SC...
# 95  ALARMD  ['AB', 'BI', 'BU', 'DE', 'NW', 'PO', 'RI', 'RM...
# 96     DNA  ['BI', 'BU', 'DE', 'NW', 'PO', 'RI', 'RM', 'SC...
#
#                                              filename  juri_count
# 0   ['AB - 1033 - Officer in trouble.docx', 'BI - ...          16
# 1   ['AB - DOMI - Domestic in progress.docx', 'BI ...          16
# 2   ['AB - FOUNDP - Found Person.docx', 'BI - FOUN...          16
# 3   ['AB - HAZARD - Hazard.docx', 'BI - HAZARD - H...          16
# 4   ['AB - IMPAIR - Impaired driver.docx', 'BI - I...          16
# ..                                                ...         ...
# 92  ['AB - INDUST - Industrial Accident.docx', 'BI...          15
# 93  ['AB - ASSMHA - Assist Mental Health Act.docx'...          15
# 94  ['BI - SPAT - Special Attention Detail Event.d...          14
# 95  ['AB - ALARMD - Domestic violence alarm.docx',...          14
# 96  ['BI - DNA - DNA collection.docx', 'BU - DNA -...          14
#
# [97 rows x 4 columns]

# %%
for x in df["juri"]:
    x =
# Out:
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'D', 'F', 'P', 'F', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'A', 'B', "'", ',', ' ', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']
# ['[', "'", 'B', 'I', "'", ',', ' ', "'", 'B', 'U', "'", ',', ' ', "'", 'D', 'E', "'", ',', ' ', "'", 'N', 'W', "'", ',', ' ', "'", 'P', 'O', "'", ',', ' ', "'", 'R', 'I', "'", ',', ' ', "'", 'R', 'M', "'", ',', ' ', "'", 'S', 'C', "'", ',', ' ', "'", 'S', 'Q', "'", ',', ' ', "'", 'S', 'X', "'", ',', ' ', "'", 'U', 'N', "'", ',', ' ', "'", 'V', 'A', "'", ',', ' ', "'", 'W', 'P', "'", ',', ' ', "'", 'W', 'V', "'", ']']

# %%
len(event_code)
# Out:
# 1989

# %%
inconsistency
# Out:
# {'Bylaw', 'Misch', 'Pursue', 'Theft'}

# %% [markdown]
# ## SITUATION

# %%
situations = []

for sop in SOPs:
    filepath = path+sop
    with open(filepath, 'rb') as f:
        source_stream = BytesIO(f.read())
    f.close()
    doc = Document(source_stream)
    paras = doc.paragraphs
    for p in paras:
        style = p.style.name
        text = para_to_text(p)
        if "heading 2" in style.lower():
            situations.append(text)

# %%
situations = set(situations)

# %% [markdown]
# ## ROLES

# %%
roles = []

for sop in SOPs:
    filepath = path+sop
    with open(filepath, 'rb') as f:
        source_stream = BytesIO(f.read())
    f.close()
    doc = Document(source_stream)
    paras = doc.paragraphs
    for p in paras:
        style = p.style.name
        text = para_to_text(p)
        if "heading 1" in style.lower():
            roles.append(text.strip())
            
roles = list(set(roles))[1:]

# %% [markdown]
# ### Extract data from acronym

# %%
import os
import json
from docx import Document
from io import StringIO, BytesIO
import re

# %%
file_path = "/Users/flu/Desktop/capstone-2020/utils/acronyms.docx"

# %%
with open(file_path, 'rb') as f:
    source_stream = BytesIO(f.read())
f.close()
doc = Document(source_stream)
paras = doc.paragraphs
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-72e021c8b637> in <module>
# ----> 1 with open(file_path, 'rb') as f:
#       2     source_stream = BytesIO(f.read())
#       3 f.close()
#       4 doc = Document(source_stream)
#       5 paras = doc.paragraphs
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/flu/Desktop/capstone-2020/utils/acronyms.docx'

# %%
import pandas as pd

df = pd.DataFrame(columns=["jargon","meaning"])
jargon = []
meaning = []

# %%
for p in paras:
    parsed = p.text.strip().split("\t")
    if len(parsed) == 2:
        jargon.append(parsed[0].strip())
        meaning.append(parsed[1].strip())

# %%
tables = doc.tables
for t in tables:
    for r in t.rows:
        i = 0
        for c in r.cells:
            if i % 2 == 0:
                i += 1
                jargon.append(c.text.strip())
            else:
                meaning.append(c.text.strip())

df["jargon"] = jargon
df["meaning"] = meaning

# %%
import numpy as np

df["jargon"].replace("",np.nan, inplace=True)
df["meaning"].replace("",np.nan, inplace=True)

# %%
df = df.dropna().reset_index()[["jargon","meaning"]]

# %%
terms = list(df["jargon"])
for term in terms:
    print(term)

# %%
definitions = list(df["meaning"])
definitions

# %% [markdown]
# #### Organization pattern

# %%
import spacy
import numpy as np

nlp = spacy.load("en_core_web_sm")

ind = 0
orgs = []

for d in definitions:
    doc = nlp(d)
    for ent in doc.ents:
        if ent.label_ == "ORG":
            orgs.append(terms[ind])
    ind += 1
orgs = list(set(orgs))

# %%
filtered = []
for org in orgs:
    if org.upper() != org:
        pass
    else:
        filtered.append(org)

# %%
filtered

# %%
org_cand = []

glossary = zip(terms, definitions)
for org, mean in glossary:
    if org in filtered:
        org_cand.append((org, mean))

# %%
org_key = ["British","Columbia",
           "Service","Services",
           "Police","Institute",
           "Ltd.", "Association",
           "Ministry","National",
           "Unit","Incorporated",
           "Corporation"]

# %%
organization = []

for x,y in org_cand:
    if len(set(org_key + y.split())) < len(org_key + y.split()):
        organization.append(x)

# %%
organization = list(set(organization))

# %% [markdown]
# ## SITUATION, ACTION, QUSETION, CONDITION

# %%
raw_texts = []

for sop in SOPs:
    filepath = path+sop
    with open(filepath, 'rb') as f:
        source_stream = BytesIO(f.read())
    f.close()
    doc = Document(source_stream)
    paras = doc.paragraphs
    for p in paras:
        style = p.style.name
        text = para_to_text(p)
        if "style1" in style.lower():
            if text.strip() == "":
                pass
            else:
                raw_texts.append(text.strip())

# %%
questions = []
conditions = []
actions = []
others = []

for t in raw_texts:
    if t.endswith("?"):
        questions.append(t)
    elif t.startswith("If"):
        conditions.append(t)
    elif nlp(t)[0].pos_ == "VERB":
        actions.append(nlp(t)[0])
    else:
        others.append(t)

# %%
questions = list(set(questions))
conditions = list(set(conditions))
actions = list(set(actions))

# %%
filtered_conditions = []
for c in conditions:
    filtered_conditions.append(c.replace("\\","").replace("/","or").replace("\t","").replace(":","").replace(";",""))

# %%
others[1300:1380]

# %% [markdown]
# ## Agency, Jurisdiction

# %%
jurisdiction = ['AB', 'BI', 'BU', 'DE', 'DFPF', 
            'NW', 'PO', 'RI', 'RM', 'SC', 
            'SQ', 'SX', 'UN', 'VA', 'WP', 
            'WV', 'DF PF']

# %% [markdown]
# ## Pattern Based Approach

# %% [markdown]
# ## Regex Based Approach

# %% [markdown]
# # Writing Entities

# %%
with open("./entity_train/PATTERNS.JSONL","w", encoding="utf-8") as f:
    
    # EVENT CODE EXTRACTION
    
    for ec in event_code:
        f.write('{"label":"EVENT", "pattern":"%s"}\n' %ec)
    for ic in inconsistency:
        f.write('{"label":"EVENT", "pattern":"%s"}\n' %ic)
    for e in events:
        f.write('{"label":"EVENT", "pattern":"%s"}\n' %e)
        
    # SITUATION EXTRACTION
    for s in situations:
        f.write('{"label":"SITUATION", "pattern":"%s"}\n' %s)
        
    # ROLE EXTRACTION
    for r in roles:
        f.write('{"label":"ROLE", "pattern":"%s"}\n' %r)
        
    # QUESTION EXTRACTION
    for q in questions:
        f.write('{"label":"QUESTION", "pattern":"%s"}\n' %q)   
        
    # CONDITION EXTRACTION
    for c in filtered_conditions:
        f.write('{"label":"CONDITION", "pattern":"%s"}\n' %c)  
        
    # ACTION EXTRACTION
    for a in actions:
        f.write('{"label":"ACTION", "pattern":"%s"}\n' %a)    
    
    # ORGANIZATION EXTRACTION
    for o in organization:
        f.write('{"label":"ORG", "pattern":"%s"}\n' %o)
    
    # JURISDICTION / AGENCY
    for j in jurisdiction:
        regex_pattern = "^({})[ -]+".format(j)
        f.write('{"label":"JURI", "pattern":[{"TEXT":{"REGEX": %s }}]}\n' %regex_pattern)
        
f.close()
